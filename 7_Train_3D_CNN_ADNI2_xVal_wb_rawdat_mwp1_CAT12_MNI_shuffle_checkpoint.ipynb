# %% [markdown]
# # Training of the CNN model and testing on the holdout test data partition (10-fold cross-validation)

# %%
# Import data from Excel sheet
import pandas as pd
df = pd.read_excel('hippocampus_volume_relevance_ADNI2.xlsx', sheet_name='ADNI2_LRP_CMP')
sid = df['subject_ID']
grp = df['Group at scan date (1=CN, 2=EMCI, 3=LMCI, 4=AD, 5=SMC)']
age = df['Age at scan']
sex = df['Sex (1=female)']
tiv = df['TIV_CAT12']
field = df['MRI_Field_Strength']
amybin = df['Amy SUVR Pos']
grpbin = (grp > 1) # 1=CN, ...

# %%
# Scan for nifti file names
import glob
dataAD = sorted(glob.glob('mwp1_MNI/AD/*.nii.gz'))
dataLMCI = sorted(glob.glob('mwp1_MNI/LMCI/*.nii.gz'))
dataCN = sorted(glob.glob('mwp1_MNI/CN/*.nii.gz'))
dataFiles = dataAD + dataLMCI + dataCN
numfiles = len(dataFiles)
print('Found ', str(numfiles), ' nifti files')
# Out:
# Found  663  nifti files

# %%
# Match covariate information
import re
import numpy as np
from keras.utils import to_categorical
debug = False
cov_idx = [-1] * numfiles # list; array: np.full((numfiles, 1), -1, dtype=int)
print('Matching covariates for loaded files ...')
for i,id in enumerate(sid):
  p = [j for j,x in enumerate(dataFiles) if re.search('_%04d_' % id, x)] # translate ID numbers to four-digit numbers, get both index and filename
  if len(p)==0:
    if debug: print('Did not find %04d' % id) # did not find Excel sheet subject ID in loaded file selection
  else:
    if debug: print('Found %04d in %s: %s' % (id, p[0], dataFiles[p[0]]))
    cov_idx[p[0]] = i # store Excel index i for data file index p[0]
print('Checking for scans not found in Excel sheet: ', sum(x<0 for x in cov_idx))

labels = pd.DataFrame({'Group':grpbin}).iloc[cov_idx, :]
labels = to_categorical(np.asarray(labels)) # use grps to access original labels
grps = pd.DataFrame({'Group':grp, 'RID':sid}).iloc[cov_idx, :]
# Out:
# Using TensorFlow backend.
# Matching covariates for loaded files ...
# Checking for scans not found in Excel sheet:  0

# %%
# Load original data from disk
import h5py
from pandas import DataFrame
hf = h5py.File('orig_images_ADNI2_wb_mwp1_CAT12_MNI.hdf5', 'r')
hf.keys # read keys
images = np.array(hf.get('images'))
hf.close()
print(images.shape)
# Out:
# (663, 100, 100, 120, 1)

# %%
# specify version of tensorflow
#%tensorflow_version 1.x  # <- use this for Google colab
import tensorflow as tf
# downgrade to specific version
#!pip install tensorflow-gpu==1.15
#import tensorflow as tf
print(tf.__version__)

# disable tensorflow deprecation warnings
import logging
logging.getLogger('tensorflow').disabled=True
# Out:
# 1.15.4

# %%
# define function for simple data augmentation (translation of 2 vx in each x/y/z direction)
# and L/R flipping
import numpy as np
def simpleshift(arr, num, axis, fill_value=0): # adapted from https://stackoverflow.com/a/42642326
  result = np.empty_like(arr)
  if (axis==1):
    if num > 0:
        result[:, :num, :, :, :] = fill_value
        result[:, num:, :, :, :] = arr[:, :-num, :, :, :]
    elif num < 0:
        result[:, num:, :, :, :] = fill_value
        result[:, :num, :, :, :] = arr[:, -num:, :, :, :]
    else:
        result[:] = arr
    return result
  elif (axis==2):
    if num > 0:
        result[:, :, :num, :, :] = fill_value
        result[:, :, num:, :, :] = arr[:, :, :-num, :, :]
    elif num < 0:
        result[:, :, num:, :, :] = fill_value
        result[:, :, :num, :, :] = arr[:, :, -num:, :, :]
    else:
        result[:] = arr
    return result
  elif (axis==3):
    if num > 0:
        result[:, :, :, :num, :] = fill_value
        result[:, :, :, num:, :] = arr[:, :, :, :-num, :]
    elif num < 0:
        result[:, :, :, num:, :] = fill_value
        result[:, :, :, :num, :] = arr[:, :, :, -num:, :]
    else:
        result[:] = arr
    return result
  else:
    return None

# %%
# helper function to obtain performance result values
def get_values(conf_matrix):
    assert conf_matrix.shape==(2,2)
    tn, fp, fn, tp = conf_matrix.ravel()
    sen = tp / (tp+fn)
    spec = tn / (fp+tn)
    ppv = tp / (tp+fp)
    npv = tn / (tn+fn)
    f1 = 2 * ((ppv * sen) / (ppv + sen))
    bacc = (spec + sen) / 2
    return bacc, sen, spec, ppv, npv, f1

# %%
# define class weights to train a balanced model, taken from https://www.tensorflow.org/tutorials/structured_data/imbalanced_data
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
neg, pos = np.bincount(labels[:, 1].astype(np.int_))
weight_for_0 = (1 / neg)*(numfiles)/2.0 
weight_for_1 = (1 / pos)*(numfiles)/2.0
class_weights = {0: weight_for_0, 1: weight_for_1}
print('Examples:    Total: {}    Positive: {} ({:.2f}% of total)'.format(
    numfiles, pos, 100 * pos / numfiles))
print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Examples:    Total: 663    Positive: 409 (61.69% of total)
# Weight for class 0: 1.31
# Weight for class 1: 0.81

# %%
# Split data into training/validation and holdout test data
from sklearn.model_selection import StratifiedKFold,train_test_split
import numpy as np
import gc
from sklearn.metrics import roc_curve, auc
from matplotlib import pyplot as plt
# %matplotlib inline
import keras
from keras import layers
from keras import models
from keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from sklearn.metrics import confusion_matrix

acc_AD, acc_MCI, auc_AD, auc_MCI = [], [], [], []
bacc_AD, bacc_MCI = [], []
sen_AD, sen_MCI, spec_AD, spec_MCI = [], [], [], []
ppv_AD, ppv_MCI, npv_AD, npv_MCI = [], [], [], []
f1_AD, f1_MCI = [], []

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=np.random.RandomState(42)) # don't seed with integer to avoid interaction with tf.set_random_seed(k)
k = 1
for train_idX, test_idX in skf.split(X=images, y=grps.iloc[:, 0]): # split data as tenfold stratified cross-validation
    print('Distribution of diagnoses in training data: [1=CN, 3=LMCI, 4=AD]')
    print(grps.iloc[train_idX, :].Group.value_counts())
    testgrps = grps.iloc[test_idX, :]
    print(list(testgrps.RID)) # print test RIDs
    print('Distribution of diagnoses in holdout test data: [1=CN, 3=LMCI, 4=AD]')
    print(testgrps.Group.value_counts())
    
    # Setup 3D CNN model
    tf.set_random_seed(k)
    input_shape = images.shape[1:]
    model = models.Sequential()

    # Convolution Layers
    model.add(layers.Conv3D(5, (3, 3, 3), padding='same', activation='relu',
              input_shape=input_shape, data_format='channels_last'))
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv3D(5, (3, 3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv3D(5, (3, 3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))
    model.add(layers.BatchNormalization())
    
    # FC layers
    model.add(layers.Flatten())
    model.add(layers.Dropout(rate = 0.1))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(rate = 0.1))
    model.add(layers.Dense(32, activation='relu', kernel_regularizer='l2'))
    model.add(layers.Dropout(rate = 0.1))
    model.add(layers.Dense(2, activation='softmax', kernel_regularizer='l2'))

    opt = keras.optimizers.Adam(lr=0.0001) # learning_rate
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    if k==1:
        model.summary()
    
    # Assign trainset and testset
    traindat = images[train_idX, :]
    train_Y = labels[train_idX, :]
    testdat = images[test_idX, :]
    test_Y = labels[test_idX, :]
    
    # Perform data augmentation
    num_train_scans = traindat.shape[0]
    num_copies = 14
    traindatA = np.zeros((num_train_scans*num_copies,) + traindat.shape[1:], dtype=traindat.dtype)
    traindatA[0:num_train_scans, :, :, :, :] = traindat
    traindatA[num_train_scans:(2*num_train_scans), :, :, :, :] = simpleshift(traindat, -10, 1) # move around x-axis
    traindatA[2*num_train_scans:(3*num_train_scans), :, :, :, :] = simpleshift(traindat, 10, 1)
    traindatA[3*num_train_scans:(4*num_train_scans), :, :, :, :] = simpleshift(traindat, -10, 2) # move around y-axis
    traindatA[4*num_train_scans:(5*num_train_scans), :, :, :, :] = simpleshift(traindat, 10, 2)
    traindatLRshifted = np.fliplr(traindat) # flip L/R
    traindatA[5*num_train_scans:(6*num_train_scans), :, :, :, :] = traindatLRshifted
    traindatA[6*num_train_scans:(7*num_train_scans), :, :, :, :] = simpleshift(traindatLRshifted, 10, 1) # move around x-axis
    traindatA[7*num_train_scans:(8*num_train_scans), :, :, :, :] = simpleshift(traindatLRshifted, -10, 1)
    traindatA[8*num_train_scans:(9*num_train_scans), :, :, :, :] = simpleshift(traindatLRshifted, 10, 2) # move around y-axis
    traindatA[9*num_train_scans:(10*num_train_scans), :, :, :, :] = simpleshift(traindatLRshifted, -10, 2)
    traindatA[10*num_train_scans:(11*num_train_scans), :, :, :, :] = simpleshift(traindat, 10, 3) # move around z-axis
    traindatA[11*num_train_scans:(12*num_train_scans), :, :, :, :] = simpleshift(traindat, -10, 3)
    traindatA[12*num_train_scans:(13*num_train_scans), :, :, :, :] = simpleshift(traindatLRshifted, 10, 3)
    traindatA[13*num_train_scans:(14*num_train_scans), :, :, :, :] = simpleshift(traindatLRshifted, -10, 3)

    train_label = np.concatenate((train_Y, train_Y, train_Y, train_Y, train_Y, train_Y, train_Y, train_Y,
                                  train_Y, train_Y, train_Y, train_Y, train_Y, train_Y),
                                 axis=0)

    # Fit model to training data
    batch_size = 20
    epochs = 20
    filepath="model_rawdat_checkpoints/rawmodel_wb_cv%d-e{epoch:02d}-{val_acc:.2f}.hdf5" % k
    filepathbest="model_rawdat_checkpoints/rawmodel_wb_cv%d.best.hdf5" % k
    hist = model.fit(traindatA, train_label, batch_size=batch_size, epochs=epochs, verbose=1, 
                     validation_data=(testdat, test_Y), shuffle=True,
                     callbacks=[
                        ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
                        ModelCheckpoint(filepathbest, monitor='val_acc', verbose=0, save_best_only=True, mode='max')],
                     class_weight=class_weights)
    # Display first models statistics
    from matplotlib import pyplot as plt
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']
    acc = hist.history['acc']
    val_acc = hist.history['val_acc']
    epochsr = range(len(loss))
    plt.figure()
    plt.plot(epochsr, loss, 'bo', label='Training loss')
    plt.plot(epochsr, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    plt.show()
    plt.figure()
    plt.plot(epochsr, acc, 'bo', label='Training acc')
    plt.plot(epochsr, val_acc, 'b', label='Validation acc')
    plt.title('Accuracy')
    plt.legend()
    plt.show()
    #mymodel = hist.model
    #print('saving model to: models/resmodel_wb_cv%d.hdf5' % k)
    #mymodel.save('models/resmodel_wb_cv%d.hdf5' % k)
    print('validating model %s' % filepathbest)
    mymodel = models.load_model(filepathbest)
    
    # Calculate accuracy for the test data
    scores = mymodel.evaluate(testdat, test_Y, batch_size=batch_size) #, verbose=0
    print("Test %s: %.2f%%" % (mymodel.metrics_names[1], scores[1]*100))
    # Calculate area under the curve (AUC)
    # adapted from: https://stackoverflow.com/questions/41032551/how-to-compute-receiving-operating-characteristic-roc-and-auc-in-keras
    pred = mymodel.predict(testdat, batch_size=batch_size)
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    acc = dict()
    for i in range(2): # classes dummy vector: 0 - CN, 1 - MCI/AD
        fpr[i], tpr[i], _ = roc_curve(test_Y[:, i], pred[:,i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    # Plot the ROC curve
    plt.figure()
    plt.plot(fpr[1], tpr[1], color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc[1])
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()
    
    testgrps = grps.iloc[test_idX, :]
    print('Distribution of diagnoses in test data: [1=CN, 3=LMCI, 4=AD]')
    print(testgrps.Group.value_counts())

    # redo AUC for binary comparison: AD vs. HC and MCI vs. HC
    for i in [3,4]:
      grpi = np.equal(testgrps.Group.to_numpy(dtype=np.int), np.ones((testgrps.shape[0],), dtype=np.int)*i)
      grp1 = np.equal(testgrps.Group.to_numpy(dtype=np.int), np.ones((testgrps.shape[0],), dtype=np.int))
      grpidx = np.logical_or(grpi, grp1)
      fpr[i], tpr[i], _ = roc_curve(test_Y[grpidx, 1], pred[grpidx, 1])
      roc_auc[i] = auc(fpr[i], tpr[i])
      acc[i] = np.mean((test_Y[grpidx, 1] == np.round(pred[grpidx, 1])).astype(int))*100

    print('AUC for MCI vs. CN = %0.3f' % roc_auc[3])
    print('AUC for AD vs. CN = %0.3f' % roc_auc[4])
    auc_AD.append(roc_auc[4])
    auc_MCI.append(roc_auc[3])
    acc_AD.append(acc[4])
    acc_MCI.append(acc[3])
    print('confusion matrix')
    confmat = confusion_matrix(testgrps.Group-1, np.round(pred[:, 1]))
    print(confmat[:,(0,1)])
    bacc, sen, spec, ppv, npv, f1 = get_values(confmat[(0,2),0:2]) # MCI
    bacc_MCI.append(bacc); sen_MCI.append(sen); spec_MCI.append(spec); ppv_MCI.append(ppv); npv_MCI.append(npv); f1_MCI.append(f1)
    bacc, sen, spec, ppv, npv, f1 = get_values(confmat[(0,3),0:2]) # AD
    bacc_AD.append(bacc); sen_AD.append(sen); spec_AD.append(spec); ppv_AD.append(ppv); npv_AD.append(npv); f1_AD.append(f1)

    k = k+1
# Out:
# Distribution of diagnoses in training data: [1=CN, 3=LMCI, 4=AD]
# 1    228
# 3    198
# 4    170
# Name: Group, dtype: int64
# [5165, 5187, 101, 42, 5241, 1010, 5146, 378, 1427, 5056, 230, 4990, 4373, 4568, 4657, 4660, 4692, 4863, 4984, 4115, 307, 150, 1418, 671, 1269, 107, 6056, 4034, 4035, 4214, 4287, 4303, 4346, 4359, 4363, 4510, 4595, 4629, 4722, 4896, 4960, 4105, 96, 56, 210, 5023, 352, 89, 1261, 4010, 4014, 4075, 4103, 4179, 4224, 4278, 4337, 4382, 4400, 4410, 4422, 4464, 4576, 4585, 4616, 4645, 4843]
# Distribution of diagnoses in holdout test data: [1=CN, 3=LMCI, 4=AD]
# 1    26
# 3    22
# 4    19
# Name: Group, dtype: int64
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 100, 100, 120, 5)  140
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 50, 50, 60, 5)     0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 60, 5)     20
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 50, 50, 60, 5)     680
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 25, 25, 30, 5)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 30, 5)     20
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 25, 25, 30, 5)     680
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 12, 12, 15, 5)     0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 15, 5)     20
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10800)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10800)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                691264
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 694,970
# Trainable params: 694,940
# Non-trainable params: 30
# _________________________________________________________________
# Train on 8344 samples, validate on 67 samples
# Epoch 1/20
# 8344/8344 [==============================] - 200s 24ms/step - loss: 1.1255 - acc: 0.5393 - val_loss: 1.0268 - val_acc: 0.6567
#
# Epoch 00001: val_acc improved from -inf to 0.65672, saving model to model_rawdat_checkpoints/rawmodel_wb_cv1-e01-0.66.hdf5
# Epoch 2/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.9561 - acc: 0.6365 - val_loss: 0.8601 - val_acc: 0.7164
#
# Epoch 00002: val_acc improved from 0.65672 to 0.71642, saving model to model_rawdat_checkpoints/rawmodel_wb_cv1-e02-0.72.hdf5
# Epoch 3/20
# 8344/8344 [==============================] - 193s 23ms/step - loss: 0.8329 - acc: 0.6913 - val_loss: 0.7468 - val_acc: 0.7164
#
# Epoch 00003: val_acc did not improve from 0.71642
# Epoch 4/20
# 8344/8344 [==============================] - 193s 23ms/step - loss: 0.7389 - acc: 0.7230 - val_loss: 0.6840 - val_acc: 0.7164
#
# Epoch 00004: val_acc did not improve from 0.71642
# Epoch 5/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.6687 - acc: 0.7372 - val_loss: 0.6499 - val_acc: 0.7015
#
# Epoch 00005: val_acc did not improve from 0.71642
# Epoch 6/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.6211 - acc: 0.7478 - val_loss: 0.6270 - val_acc: 0.7612
#
# Epoch 00006: val_acc improved from 0.71642 to 0.76119, saving model to model_rawdat_checkpoints/rawmodel_wb_cv1-e06-0.76.hdf5
# Epoch 7/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.5762 - acc: 0.7616 - val_loss: 0.5929 - val_acc: 0.7164
#
# Epoch 00007: val_acc did not improve from 0.76119
# Epoch 8/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.5463 - acc: 0.7688 - val_loss: 0.6227 - val_acc: 0.7164
#
# Epoch 00008: val_acc did not improve from 0.76119
# Epoch 9/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.5128 - acc: 0.7818 - val_loss: 0.5790 - val_acc: 0.7164
#
# Epoch 00009: val_acc did not improve from 0.76119
# Epoch 10/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.4884 - acc: 0.7901 - val_loss: 0.5934 - val_acc: 0.7313
#
# Epoch 00010: val_acc did not improve from 0.76119
# Epoch 11/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.4652 - acc: 0.7965 - val_loss: 0.6096 - val_acc: 0.7015
#
# Epoch 00011: val_acc did not improve from 0.76119
# Epoch 12/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.4315 - acc: 0.8219 - val_loss: 0.6286 - val_acc: 0.7164
#
# Epoch 00012: val_acc did not improve from 0.76119
# Epoch 13/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.4038 - acc: 0.8316 - val_loss: 0.6277 - val_acc: 0.6866
#
# Epoch 00013: val_acc did not improve from 0.76119
# Epoch 14/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.3747 - acc: 0.8478 - val_loss: 0.6909 - val_acc: 0.7313
#
# Epoch 00014: val_acc did not improve from 0.76119
# Epoch 15/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.3500 - acc: 0.8576 - val_loss: 0.7514 - val_acc: 0.7015
#
# Epoch 00015: val_acc did not improve from 0.76119
# Epoch 16/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.3203 - acc: 0.8697 - val_loss: 0.7067 - val_acc: 0.6418
#
# Epoch 00016: val_acc did not improve from 0.76119
# Epoch 17/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.2871 - acc: 0.8889 - val_loss: 0.8269 - val_acc: 0.6716
#
# Epoch 00017: val_acc did not improve from 0.76119
# Epoch 18/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.2574 - acc: 0.9038 - val_loss: 0.8026 - val_acc: 0.7015
#
# Epoch 00018: val_acc did not improve from 0.76119
# Epoch 19/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.2318 - acc: 0.9184 - val_loss: 0.9082 - val_acc: 0.7015
#
# Epoch 00019: val_acc did not improve from 0.76119
# Epoch 20/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.2150 - acc: 0.9275 - val_loss: 0.9074 - val_acc: 0.7164
#
# Epoch 00020: val_acc did not improve from 0.76119
# validating model model_rawdat_checkpoints/rawmodel_wb_cv1.best.hdf5
# 67/67 [==============================] - 1s 11ms/step
# Test acc: 76.12%
# Distribution of diagnoses in test data: [1=CN, 3=LMCI, 4=AD]
# 1    26
# 3    22
# 4    19
# Name: Group, dtype: int64
# AUC for MCI vs. CN = 0.733
# AUC for AD vs. CN = 0.921
# confusion matrix
# [[24  2]
#  [ 0  0]
#  [11 11]
#  [ 3 16]]
# Distribution of diagnoses in training data: [1=CN, 3=LMCI, 4=AD]
# 1    228
# 3    198
# 4    170
# Name: Group, dtype: int64
# [702, 5251, 376, 906, 5063, 5162, 5062, 269, 51, 4992, 5058, 873, 1255, 6142, 4252, 4549, 4783, 4827, 4954, 908, 4543, 1046, 4945, 4630, 1226, 5047, 1300, 200, 123, 1414, 1186, 4030, 4077, 4131, 4197, 4366, 4515, 4605, 4777, 4782, 4955, 1190, 479, 1016, 4050, 260, 545, 301, 668, 6051, 4021, 4086, 4093, 4148, 4196, 4262, 4269, 4343, 4348, 4365, 4367, 4474, 4483, 4505, 4516, 4599, 4612]
# Distribution of diagnoses in holdout test data: [1=CN, 3=LMCI, 4=AD]
# 1    26
# 3    22
# 4    19
# Name: Group, dtype: int64
# Train on 8344 samples, validate on 67 samples
# Epoch 1/20
# 8344/8344 [==============================] - 193s 23ms/step - loss: 1.1298 - acc: 0.5600 - val_loss: 1.0288 - val_acc: 0.6119
#
# Epoch 00001: val_acc improved from -inf to 0.61194, saving model to model_rawdat_checkpoints/rawmodel_wb_cv2-e01-0.61.hdf5
# Epoch 2/20
# 8344/8344 [==============================] - 190s 23ms/step - loss: 0.9656 - acc: 0.6437 - val_loss: 0.8539 - val_acc: 0.7164
#
# Epoch 00002: val_acc improved from 0.61194 to 0.71642, saving model to model_rawdat_checkpoints/rawmodel_wb_cv2-e02-0.72.hdf5
# Epoch 3/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.8372 - acc: 0.6870 - val_loss: 0.7525 - val_acc: 0.7164
#
# Epoch 00003: val_acc did not improve from 0.71642
# Epoch 4/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.7391 - acc: 0.7157 - val_loss: 0.6656 - val_acc: 0.7612
#
# Epoch 00004: val_acc improved from 0.71642 to 0.76119, saving model to model_rawdat_checkpoints/rawmodel_wb_cv2-e04-0.76.hdf5
# Epoch 5/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.6703 - acc: 0.7386 - val_loss: 0.5962 - val_acc: 0.7612
#
# Epoch 00005: val_acc did not improve from 0.76119
# Epoch 6/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.6136 - acc: 0.7506 - val_loss: 0.5936 - val_acc: 0.7761
#
# Epoch 00006: val_acc improved from 0.76119 to 0.77612, saving model to model_rawdat_checkpoints/rawmodel_wb_cv2-e06-0.78.hdf5
# Epoch 7/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.5728 - acc: 0.7584 - val_loss: 0.5400 - val_acc: 0.7910
#
# Epoch 00007: val_acc improved from 0.77612 to 0.79104, saving model to model_rawdat_checkpoints/rawmodel_wb_cv2-e07-0.79.hdf5
# Epoch 8/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.5478 - acc: 0.7688 - val_loss: 0.5616 - val_acc: 0.7463
#
# Epoch 00008: val_acc did not improve from 0.79104
# Epoch 9/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.5095 - acc: 0.7833 - val_loss: 0.5357 - val_acc: 0.7313
#
# Epoch 00009: val_acc did not improve from 0.79104
# Epoch 10/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.4807 - acc: 0.7918 - val_loss: 0.5239 - val_acc: 0.7313
#
# Epoch 00010: val_acc did not improve from 0.79104
# Epoch 11/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.4563 - acc: 0.8027 - val_loss: 0.5242 - val_acc: 0.7164
#
# Epoch 00011: val_acc did not improve from 0.79104
# Epoch 12/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.4235 - acc: 0.8248 - val_loss: 0.5061 - val_acc: 0.7612
#
# Epoch 00012: val_acc did not improve from 0.79104
# Epoch 13/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.3959 - acc: 0.8413 - val_loss: 0.5350 - val_acc: 0.7612
#
# Epoch 00013: val_acc did not improve from 0.79104
# Epoch 14/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.3802 - acc: 0.8435 - val_loss: 0.5464 - val_acc: 0.7612
#
# Epoch 00014: val_acc did not improve from 0.79104
# Epoch 15/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.3526 - acc: 0.8615 - val_loss: 0.5894 - val_acc: 0.7612
#
# Epoch 00015: val_acc did not improve from 0.79104
# Epoch 16/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.3336 - acc: 0.8682 - val_loss: 0.5974 - val_acc: 0.7463
#
# Epoch 00016: val_acc did not improve from 0.79104
# Epoch 17/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.3016 - acc: 0.8858 - val_loss: 0.4977 - val_acc: 0.7761
#
# Epoch 00017: val_acc did not improve from 0.79104
# Epoch 18/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.2841 - acc: 0.8927 - val_loss: 0.6876 - val_acc: 0.7164
#
# Epoch 00018: val_acc did not improve from 0.79104
# Epoch 19/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.2626 - acc: 0.9012 - val_loss: 0.5778 - val_acc: 0.7612
#
# Epoch 00019: val_acc did not improve from 0.79104
# Epoch 20/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.2425 - acc: 0.9132 - val_loss: 0.5770 - val_acc: 0.7463
#
# Epoch 00020: val_acc did not improve from 0.79104
# validating model model_rawdat_checkpoints/rawmodel_wb_cv2.best.hdf5
# 67/67 [==============================] - 1s 13ms/step
# Test acc: 79.10%
# Distribution of diagnoses in test data: [1=CN, 3=LMCI, 4=AD]
# 1    26
# 3    22
# 4    19
# Name: Group, dtype: int64
# AUC for MCI vs. CN = 0.808
# AUC for AD vs. CN = 0.911
# confusion matrix
# [[23  3]
#  [ 0  0]
#  [ 9 13]
#  [ 2 17]]
# Distribution of diagnoses in training data: [1=CN, 3=LMCI, 4=AD]
# 1    228
# 3    198
# 4    170
# Name: Group, dtype: int64
# [5119, 5037, 5252, 5240, 552, 1425, 5070, 5090, 5015, 973, 4089, 4195, 4258, 4477, 4526, 4732, 4755, 4772, 4867, 4229, 1122, 420, 4922, 644, 4729, 1318, 454, 1408, 4250, 717, 6297, 4015, 4053, 4061, 4169, 4240, 4524, 4562, 4857, 4889, 4976, 4213, 4872, 1206, 4097, 734, 1098, 934, 4234, 896, 657, 186, 4032, 4043, 4092, 4100, 4121, 4151, 4288, 4369, 4372, 4376, 4559, 4577, 4649, 4832, 4855]
# Distribution of diagnoses in holdout test data: [1=CN, 3=LMCI, 4=AD]
# 1    26
# 3    22
# 4    19
# Name: Group, dtype: int64
# Train on 8344 samples, validate on 67 samples
# Epoch 1/20
# 8344/8344 [==============================] - 193s 23ms/step - loss: 1.1447 - acc: 0.5073 - val_loss: 1.0792 - val_acc: 0.4478
#
# Epoch 00001: val_acc improved from -inf to 0.44776, saving model to model_rawdat_checkpoints/rawmodel_wb_cv3-e01-0.45.hdf5
# Epoch 2/20
# 8344/8344 [==============================] - 190s 23ms/step - loss: 1.0068 - acc: 0.5804 - val_loss: 0.9484 - val_acc: 0.5970
#
# Epoch 00002: val_acc improved from 0.44776 to 0.59701, saving model to model_rawdat_checkpoints/rawmodel_wb_cv3-e02-0.60.hdf5
# Epoch 3/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.8690 - acc: 0.6717 - val_loss: 0.9542 - val_acc: 0.6418
#
# Epoch 00003: val_acc improved from 0.59701 to 0.64179, saving model to model_rawdat_checkpoints/rawmodel_wb_cv3-e03-0.64.hdf5
# Epoch 4/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.7529 - acc: 0.7194 - val_loss: 0.8524 - val_acc: 0.6418
#
# Epoch 00004: val_acc improved from 0.64179 to 0.64179, saving model to model_rawdat_checkpoints/rawmodel_wb_cv3-e04-0.64.hdf5
# Epoch 5/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.6689 - acc: 0.7476 - val_loss: 0.7897 - val_acc: 0.6269
#
# Epoch 00005: val_acc did not improve from 0.64179
# Epoch 6/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.6081 - acc: 0.7683 - val_loss: 0.7690 - val_acc: 0.6567
#
# Epoch 00006: val_acc improved from 0.64179 to 0.65672, saving model to model_rawdat_checkpoints/rawmodel_wb_cv3-e06-0.66.hdf5
# Epoch 7/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.5630 - acc: 0.7764 - val_loss: 0.7070 - val_acc: 0.6567
#
# Epoch 00007: val_acc did not improve from 0.65672
# Epoch 8/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.5179 - acc: 0.7870 - val_loss: 0.6943 - val_acc: 0.7015
#
# Epoch 00008: val_acc improved from 0.65672 to 0.70149, saving model to model_rawdat_checkpoints/rawmodel_wb_cv3-e08-0.70.hdf5
# Epoch 9/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.4831 - acc: 0.8026 - val_loss: 0.6603 - val_acc: 0.7164
#
# Epoch 00009: val_acc improved from 0.70149 to 0.71642, saving model to model_rawdat_checkpoints/rawmodel_wb_cv3-e09-0.72.hdf5
# Epoch 10/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.4487 - acc: 0.8196 - val_loss: 0.6754 - val_acc: 0.7015
#
# Epoch 00010: val_acc did not improve from 0.71642
# Epoch 11/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.4114 - acc: 0.8359 - val_loss: 0.6765 - val_acc: 0.7463
#
# Epoch 00011: val_acc improved from 0.71642 to 0.74627, saving model to model_rawdat_checkpoints/rawmodel_wb_cv3-e11-0.75.hdf5
# Epoch 12/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.3785 - acc: 0.8535 - val_loss: 0.6959 - val_acc: 0.7164
#
# Epoch 00012: val_acc did not improve from 0.74627
# Epoch 13/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.3511 - acc: 0.8652 - val_loss: 0.7459 - val_acc: 0.7164
#
# Epoch 00013: val_acc did not improve from 0.74627
# Epoch 14/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.3184 - acc: 0.8820 - val_loss: 0.8279 - val_acc: 0.6866
#
# Epoch 00014: val_acc did not improve from 0.74627
# Epoch 15/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.2910 - acc: 0.8943 - val_loss: 0.8366 - val_acc: 0.7015
#
# Epoch 00015: val_acc did not improve from 0.74627
# Epoch 16/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.2683 - acc: 0.9028 - val_loss: 0.9760 - val_acc: 0.7015
#
# Epoch 00016: val_acc did not improve from 0.74627
# Epoch 17/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.2416 - acc: 0.9172 - val_loss: 0.8167 - val_acc: 0.6866
#
# Epoch 00017: val_acc did not improve from 0.74627
# Epoch 18/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.2171 - acc: 0.9320 - val_loss: 1.0427 - val_acc: 0.6866
#
# Epoch 00018: val_acc did not improve from 0.74627
# Epoch 19/20
# 8344/8344 [==============================] - 191s 23ms/step - loss: 0.2033 - acc: 0.9347 - val_loss: 0.8574 - val_acc: 0.7015
#
# Epoch 00019: val_acc did not improve from 0.74627
# Epoch 20/20
# 8344/8344 [==============================] - 192s 23ms/step - loss: 0.1903 - acc: 0.9396 - val_loss: 0.8529 - val_acc: 0.7164
#
# Epoch 00020: val_acc did not improve from 0.74627
# validating model model_rawdat_checkpoints/rawmodel_wb_cv3.best.hdf5
# 67/67 [==============================] - 1s 15ms/step
# Test acc: 74.63%
# Distribution of diagnoses in test data: [1=CN, 3=LMCI, 4=AD]
# 1    26
# 3    22
# 4    19
# Name: Group, dtype: int64
# AUC for MCI vs. CN = 0.624
# AUC for AD vs. CN = 0.917
# confusion matrix
# [[23  3]
#  [ 0  0]
#  [12 10]
#  [ 2 17]]
# Distribution of diagnoses in training data: [1=CN, 3=LMCI, 4=AD]
# 1    229
# 3    198
# 4    170
# Name: Group, dtype: int64
# [572, 1030, 6303, 1326, 830, 5087, 997, 5059, 5138, 4215, 4223, 4307, 4672, 4696, 4730, 4770, 4792, 4912, 4962, 4985, 142, 6356, 1045, 4203, 4714, 1380, 4167, 1419, 778, 6274, 4219, 4243, 4293, 4414, 4444, 4646, 4736, 4769, 4815, 4888, 4904, 4270, 610, 498, 842, 985, 920, 171, 113, 4037, 4084, 4275, 4340, 4349, 4393, 4401, 4469, 4482, 4485, 4503, 4545, 4566, 4598, 4609, 4762, 4835]
# Distribution of diagnoses in holdout test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# Train on 8358 samples, validate on 66 samples
# Epoch 1/20
# 8358/8358 [==============================] - 199s 24ms/step - loss: 1.1525 - acc: 0.5164 - val_loss: 1.0756 - val_acc: 0.6212
#
# Epoch 00001: val_acc improved from -inf to 0.62121, saving model to model_rawdat_checkpoints/rawmodel_wb_cv4-e01-0.62.hdf5
# Epoch 2/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 1.0431 - acc: 0.5592 - val_loss: 1.0019 - val_acc: 0.6061
#
# Epoch 00002: val_acc did not improve from 0.62121
# Epoch 3/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.9618 - acc: 0.5695 - val_loss: 0.9247 - val_acc: 0.6061
#
# Epoch 00003: val_acc did not improve from 0.62121
# Epoch 4/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.8808 - acc: 0.6046 - val_loss: 0.9007 - val_acc: 0.5606
#
# Epoch 00004: val_acc did not improve from 0.62121
# Epoch 5/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.7818 - acc: 0.6704 - val_loss: 0.6907 - val_acc: 0.6818
#
# Epoch 00005: val_acc improved from 0.62121 to 0.68182, saving model to model_rawdat_checkpoints/rawmodel_wb_cv4-e05-0.68.hdf5
# Epoch 6/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.7105 - acc: 0.6961 - val_loss: 0.6561 - val_acc: 0.6970
#
# Epoch 00006: val_acc improved from 0.68182 to 0.69697, saving model to model_rawdat_checkpoints/rawmodel_wb_cv4-e06-0.70.hdf5
# Epoch 7/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.6421 - acc: 0.7266 - val_loss: 0.6540 - val_acc: 0.6970
#
# Epoch 00007: val_acc improved from 0.69697 to 0.69697, saving model to model_rawdat_checkpoints/rawmodel_wb_cv4-e07-0.70.hdf5
# Epoch 8/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5825 - acc: 0.7495 - val_loss: 0.5575 - val_acc: 0.7576
#
# Epoch 00008: val_acc improved from 0.69697 to 0.75758, saving model to model_rawdat_checkpoints/rawmodel_wb_cv4-e08-0.76.hdf5
# Epoch 9/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5258 - acc: 0.7722 - val_loss: 0.5667 - val_acc: 0.7273
#
# Epoch 00009: val_acc did not improve from 0.75758
# Epoch 10/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4794 - acc: 0.7936 - val_loss: 0.5381 - val_acc: 0.7879
#
# Epoch 00010: val_acc improved from 0.75758 to 0.78788, saving model to model_rawdat_checkpoints/rawmodel_wb_cv4-e10-0.79.hdf5
# Epoch 11/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4334 - acc: 0.8207 - val_loss: 0.6884 - val_acc: 0.6667
#
# Epoch 00011: val_acc did not improve from 0.78788
# Epoch 12/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3811 - acc: 0.8448 - val_loss: 0.5866 - val_acc: 0.7576
#
# Epoch 00012: val_acc did not improve from 0.78788
# Epoch 13/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3374 - acc: 0.8674 - val_loss: 0.5834 - val_acc: 0.7121
#
# Epoch 00013: val_acc did not improve from 0.78788
# Epoch 14/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.2880 - acc: 0.8926 - val_loss: 0.6048 - val_acc: 0.7273
#
# Epoch 00014: val_acc did not improve from 0.78788
# Epoch 15/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.2421 - acc: 0.9180 - val_loss: 0.6842 - val_acc: 0.7576
#
# Epoch 00015: val_acc did not improve from 0.78788
# Epoch 16/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.2018 - acc: 0.9403 - val_loss: 0.7340 - val_acc: 0.7424
#
# Epoch 00016: val_acc did not improve from 0.78788
# Epoch 17/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.1779 - acc: 0.9508 - val_loss: 0.6877 - val_acc: 0.7273
#
# Epoch 00017: val_acc did not improve from 0.78788
# Epoch 18/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.1464 - acc: 0.9657 - val_loss: 0.7917 - val_acc: 0.7576
#
# Epoch 00018: val_acc did not improve from 0.78788
# Epoch 19/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.1261 - acc: 0.9748 - val_loss: 0.8383 - val_acc: 0.7273
#
# Epoch 00019: val_acc did not improve from 0.78788
# Epoch 20/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.1199 - acc: 0.9755 - val_loss: 0.8835 - val_acc: 0.7121
#
# Epoch 00020: val_acc did not improve from 0.78788
# validating model model_rawdat_checkpoints/rawmodel_wb_cv4.best.hdf5
# 66/66 [==============================] - 1s 17ms/step
# Test acc: 78.79%
# Distribution of diagnoses in test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# AUC for MCI vs. CN = 0.758
# AUC for AD vs. CN = 0.928
# confusion matrix
# [[19  6]
#  [ 0  0]
#  [ 6 16]
#  [ 2 17]]
# Distribution of diagnoses in training data: [1=CN, 3=LMCI, 4=AD]
# 1    229
# 3    198
# 4    170
# Name: Group, dtype: int64
# [1130, 408, 292, 4859, 4968, 5184, 4009, 4024, 4039, 4152, 4153, 4201, 4546, 4589, 4591, 4641, 4774, 4911, 5012, 6258, 546, 6427, 1218, 1072, 746, 4311, 296, 4542, 4029, 4058, 4122, 4170, 4395, 4596, 4636, 4689, 4713, 4723, 4743, 4757, 4925, 419, 159, 58, 61, 120, 59, 1232, 272, 969, 1195, 1202, 4173, 4225, 4290, 4308, 4313, 4399, 4604, 4607, 4620, 4644, 4652, 4856, 4951, 4952]
# Distribution of diagnoses in holdout test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# Train on 8358 samples, validate on 66 samples
# Epoch 1/20
# 8358/8358 [==============================] - 195s 23ms/step - loss: 1.1234 - acc: 0.5063 - val_loss: 1.0498 - val_acc: 0.6061
#
# Epoch 00001: val_acc improved from -inf to 0.60606, saving model to model_rawdat_checkpoints/rawmodel_wb_cv5-e01-0.61.hdf5
# Epoch 2/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 1.0133 - acc: 0.5519 - val_loss: 0.9692 - val_acc: 0.5455
#
# Epoch 00002: val_acc did not improve from 0.60606
# Epoch 3/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.8970 - acc: 0.6283 - val_loss: 0.8712 - val_acc: 0.6212
#
# Epoch 00003: val_acc improved from 0.60606 to 0.62121, saving model to model_rawdat_checkpoints/rawmodel_wb_cv5-e03-0.62.hdf5
# Epoch 4/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.7837 - acc: 0.6808 - val_loss: 0.9052 - val_acc: 0.5909
#
# Epoch 00004: val_acc did not improve from 0.62121
# Epoch 5/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.7005 - acc: 0.7131 - val_loss: 0.7661 - val_acc: 0.6818
#
# Epoch 00005: val_acc improved from 0.62121 to 0.68182, saving model to model_rawdat_checkpoints/rawmodel_wb_cv5-e05-0.68.hdf5
# Epoch 6/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.6229 - acc: 0.7467 - val_loss: 0.7469 - val_acc: 0.6667
#
# Epoch 00006: val_acc did not improve from 0.68182
# Epoch 7/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5648 - acc: 0.7791 - val_loss: 0.7307 - val_acc: 0.6515
#
# Epoch 00007: val_acc did not improve from 0.68182
# Epoch 8/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.5073 - acc: 0.8006 - val_loss: 0.7580 - val_acc: 0.6667
#
# Epoch 00008: val_acc did not improve from 0.68182
# Epoch 9/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.4560 - acc: 0.8330 - val_loss: 0.7866 - val_acc: 0.6667
#
# Epoch 00009: val_acc did not improve from 0.68182
# Epoch 10/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.4155 - acc: 0.8476 - val_loss: 0.8991 - val_acc: 0.6818
#
# Epoch 00010: val_acc did not improve from 0.68182
# Epoch 11/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3702 - acc: 0.8717 - val_loss: 0.7727 - val_acc: 0.6212
#
# Epoch 00011: val_acc did not improve from 0.68182
# Epoch 12/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3325 - acc: 0.8885 - val_loss: 0.8485 - val_acc: 0.6515
#
# Epoch 00012: val_acc did not improve from 0.68182
# Epoch 13/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.2975 - acc: 0.9003 - val_loss: 0.9558 - val_acc: 0.6515
#
# Epoch 00013: val_acc did not improve from 0.68182
# Epoch 14/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.2689 - acc: 0.9171 - val_loss: 0.9832 - val_acc: 0.6818
#
# Epoch 00014: val_acc did not improve from 0.68182
# Epoch 15/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.2343 - acc: 0.9299 - val_loss: 0.9782 - val_acc: 0.6212
#
# Epoch 00015: val_acc did not improve from 0.68182
# Epoch 16/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.2111 - acc: 0.9397 - val_loss: 1.0708 - val_acc: 0.6667
#
# Epoch 00016: val_acc did not improve from 0.68182
# Epoch 17/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.1846 - acc: 0.9543 - val_loss: 1.1500 - val_acc: 0.6515
#
# Epoch 00017: val_acc did not improve from 0.68182
# Epoch 18/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.1671 - acc: 0.9612 - val_loss: 1.1942 - val_acc: 0.6818
#
# Epoch 00018: val_acc did not improve from 0.68182
# Epoch 19/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.1552 - acc: 0.9626 - val_loss: 1.3383 - val_acc: 0.7121
#
# Epoch 00019: val_acc improved from 0.68182 to 0.71212, saving model to model_rawdat_checkpoints/rawmodel_wb_cv5-e19-0.71.hdf5
# Epoch 20/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.1313 - acc: 0.9750 - val_loss: 1.2714 - val_acc: 0.6970
#
# Epoch 00020: val_acc did not improve from 0.71212
# validating model model_rawdat_checkpoints/rawmodel_wb_cv5.best.hdf5
# 66/66 [==============================] - 1s 19ms/step
# Test acc: 71.21%
# Distribution of diagnoses in test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# AUC for MCI vs. CN = 0.640
# AUC for AD vs. CN = 0.888
# confusion matrix
# [[13 12]
#  [ 0  0]
#  [ 6 16]
#  [ 1 18]]
# Distribution of diagnoses in training data: [1=CN, 3=LMCI, 4=AD]
# 1    229
# 3    198
# 4    170
# Name: Group, dtype: int64
# [5038, 887, 4964, 5013, 5017, 4980, 1346, 5029, 667, 6039, 5231, 5275, 4379, 4583, 4737, 4905, 4906, 4982, 5019, 4804, 679, 919, 4300, 800, 1268, 4042, 4094, 4138, 4210, 4244, 4458, 4582, 4654, 4741, 4767, 4793, 4873, 4885, 4929, 4936, 4943, 618, 173, 229, 863, 722, 767, 4255, 1280, 4026, 4041, 4076, 4125, 4155, 4177, 4292, 4345, 4352, 4391, 4441, 4555, 4637, 4638, 4643, 4878, 4900]
# Distribution of diagnoses in holdout test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# Train on 8358 samples, validate on 66 samples
# Epoch 1/20
# 8358/8358 [==============================] - 196s 23ms/step - loss: 1.1109 - acc: 0.5080 - val_loss: 1.0288 - val_acc: 0.6515
#
# Epoch 00001: val_acc improved from -inf to 0.65152, saving model to model_rawdat_checkpoints/rawmodel_wb_cv6-e01-0.65.hdf5
# Epoch 2/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.9853 - acc: 0.5544 - val_loss: 0.8974 - val_acc: 0.6515
#
# Epoch 00002: val_acc did not improve from 0.65152
# Epoch 3/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.8474 - acc: 0.6535 - val_loss: 0.6932 - val_acc: 0.8030
#
# Epoch 00003: val_acc improved from 0.65152 to 0.80303, saving model to model_rawdat_checkpoints/rawmodel_wb_cv6-e03-0.80.hdf5
# Epoch 4/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.7326 - acc: 0.6971 - val_loss: 0.6230 - val_acc: 0.8030
#
# Epoch 00004: val_acc did not improve from 0.80303
# Epoch 5/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.6629 - acc: 0.7212 - val_loss: 0.6378 - val_acc: 0.7424
#
# Epoch 00005: val_acc did not improve from 0.80303
# Epoch 6/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.6098 - acc: 0.7246 - val_loss: 0.5652 - val_acc: 0.8182
#
# Epoch 00006: val_acc improved from 0.80303 to 0.81818, saving model to model_rawdat_checkpoints/rawmodel_wb_cv6-e06-0.82.hdf5
# Epoch 7/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5752 - acc: 0.7393 - val_loss: 0.5593 - val_acc: 0.8182
#
# Epoch 00007: val_acc did not improve from 0.81818
# Epoch 8/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5436 - acc: 0.7502 - val_loss: 0.5469 - val_acc: 0.7879
#
# Epoch 00008: val_acc did not improve from 0.81818
# Epoch 9/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5179 - acc: 0.7580 - val_loss: 0.5399 - val_acc: 0.7879
#
# Epoch 00009: val_acc did not improve from 0.81818
# Epoch 10/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5015 - acc: 0.7633 - val_loss: 0.5472 - val_acc: 0.8030
#
# Epoch 00010: val_acc did not improve from 0.81818
# Epoch 11/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.4777 - acc: 0.7743 - val_loss: 0.5562 - val_acc: 0.7727
#
# Epoch 00011: val_acc did not improve from 0.81818
# Epoch 12/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.4505 - acc: 0.7852 - val_loss: 0.5584 - val_acc: 0.7576
#
# Epoch 00012: val_acc did not improve from 0.81818
# Epoch 13/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.4359 - acc: 0.7959 - val_loss: 0.5699 - val_acc: 0.8030
#
# Epoch 00013: val_acc did not improve from 0.81818
# Epoch 14/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.4194 - acc: 0.8070 - val_loss: 0.5793 - val_acc: 0.8182
#
# Epoch 00014: val_acc did not improve from 0.81818
# Epoch 15/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.4001 - acc: 0.8123 - val_loss: 0.5948 - val_acc: 0.8030
#
# Epoch 00015: val_acc did not improve from 0.81818
# Epoch 16/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.3859 - acc: 0.8232 - val_loss: 0.5831 - val_acc: 0.8030
#
# Epoch 00016: val_acc did not improve from 0.81818
# Epoch 17/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.3622 - acc: 0.8379 - val_loss: 0.6348 - val_acc: 0.8030
#
# Epoch 00017: val_acc did not improve from 0.81818
# Epoch 18/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.3465 - acc: 0.8475 - val_loss: 0.6265 - val_acc: 0.8182
#
# Epoch 00018: val_acc did not improve from 0.81818
# Epoch 19/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.3306 - acc: 0.8557 - val_loss: 0.6558 - val_acc: 0.7879
#
# Epoch 00019: val_acc did not improve from 0.81818
# Epoch 20/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.3133 - acc: 0.8677 - val_loss: 0.7011 - val_acc: 0.8333
#
# Epoch 00020: val_acc improved from 0.81818 to 0.83333, saving model to model_rawdat_checkpoints/rawmodel_wb_cv6-e20-0.83.hdf5
# validating model model_rawdat_checkpoints/rawmodel_wb_cv6.best.hdf5
# 66/66 [==============================] - 1s 20ms/step
# Test acc: 83.33%
# Distribution of diagnoses in test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# AUC for MCI vs. CN = 0.787
# AUC for AD vs. CN = 0.918
# confusion matrix
# [[20  5]
#  [ 0  0]
#  [ 5 17]
#  [ 1 18]]
# Distribution of diagnoses in training data: [1=CN, 3=LMCI, 4=AD]
# 1    229
# 3    198
# 4    170
# Name: Group, dtype: int64
# [5196, 5027, 5071, 1117, 5112, 5005, 4959, 4994, 5106, 166, 5028, 135, 1043, 4136, 4686, 4820, 4887, 4910, 4940, 6073, 1063, 867, 4899, 1118, 925, 4928, 505, 1052, 4263, 4324, 4381, 4406, 4430, 4502, 4521, 4626, 4721, 4746, 4750, 4784, 4877, 907, 981, 553, 130, 31, 926, 741, 257, 172, 21, 413, 4080, 4090, 4174, 4218, 4276, 4320, 4350, 4371, 4385, 4388, 4396, 4488, 4558, 4921]
# Distribution of diagnoses in holdout test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# Train on 8358 samples, validate on 66 samples
# Epoch 1/20
# 8358/8358 [==============================] - 196s 23ms/step - loss: 1.1247 - acc: 0.5419 - val_loss: 0.9368 - val_acc: 0.7727
#
# Epoch 00001: val_acc improved from -inf to 0.77273, saving model to model_rawdat_checkpoints/rawmodel_wb_cv7-e01-0.77.hdf5
# Epoch 2/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.9659 - acc: 0.6165 - val_loss: 0.8970 - val_acc: 0.6364
#
# Epoch 00002: val_acc did not improve from 0.77273
# Epoch 3/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.8126 - acc: 0.6882 - val_loss: 0.7103 - val_acc: 0.7727
#
# Epoch 00003: val_acc improved from 0.77273 to 0.77273, saving model to model_rawdat_checkpoints/rawmodel_wb_cv7-e03-0.77.hdf5
# Epoch 4/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.7149 - acc: 0.7138 - val_loss: 0.5976 - val_acc: 0.8182
#
# Epoch 00004: val_acc improved from 0.77273 to 0.81818, saving model to model_rawdat_checkpoints/rawmodel_wb_cv7-e04-0.82.hdf5
# Epoch 5/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.6452 - acc: 0.7346 - val_loss: 0.5700 - val_acc: 0.7576
#
# Epoch 00005: val_acc did not improve from 0.81818
# Epoch 6/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5996 - acc: 0.7444 - val_loss: 0.5886 - val_acc: 0.6970
#
# Epoch 00006: val_acc did not improve from 0.81818
# Epoch 7/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5650 - acc: 0.7513 - val_loss: 0.5102 - val_acc: 0.7727
#
# Epoch 00007: val_acc did not improve from 0.81818
# Epoch 8/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5367 - acc: 0.7639 - val_loss: 0.4907 - val_acc: 0.8182
#
# Epoch 00008: val_acc did not improve from 0.81818
# Epoch 9/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5119 - acc: 0.7714 - val_loss: 0.4752 - val_acc: 0.8182
#
# Epoch 00009: val_acc improved from 0.81818 to 0.81818, saving model to model_rawdat_checkpoints/rawmodel_wb_cv7-e09-0.82.hdf5
# Epoch 10/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.4817 - acc: 0.7831 - val_loss: 0.4922 - val_acc: 0.7879
#
# Epoch 00010: val_acc did not improve from 0.81818
# Epoch 11/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4577 - acc: 0.7928 - val_loss: 0.5023 - val_acc: 0.7879
#
# Epoch 00011: val_acc did not improve from 0.81818
# Epoch 12/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4288 - acc: 0.8094 - val_loss: 0.5354 - val_acc: 0.7727
#
# Epoch 00012: val_acc did not improve from 0.81818
# Epoch 13/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4122 - acc: 0.8157 - val_loss: 0.5716 - val_acc: 0.7424
#
# Epoch 00013: val_acc did not improve from 0.81818
# Epoch 14/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3739 - acc: 0.8378 - val_loss: 0.6051 - val_acc: 0.7727
#
# Epoch 00014: val_acc did not improve from 0.81818
# Epoch 15/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3495 - acc: 0.8500 - val_loss: 0.6023 - val_acc: 0.8182
#
# Epoch 00015: val_acc did not improve from 0.81818
# Epoch 16/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3093 - acc: 0.8726 - val_loss: 0.7747 - val_acc: 0.7273
#
# Epoch 00016: val_acc did not improve from 0.81818
# Epoch 17/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.2851 - acc: 0.8833 - val_loss: 0.6711 - val_acc: 0.7424
#
# Epoch 00017: val_acc did not improve from 0.81818
# Epoch 18/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.2505 - acc: 0.9070 - val_loss: 0.6745 - val_acc: 0.7727
#
# Epoch 00018: val_acc did not improve from 0.81818
# Epoch 19/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.2236 - acc: 0.9206 - val_loss: 0.8002 - val_acc: 0.7576
#
# Epoch 00019: val_acc did not improve from 0.81818
# Epoch 20/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.1967 - acc: 0.9399 - val_loss: 0.9342 - val_acc: 0.7424
#
# Epoch 00020: val_acc did not improve from 0.81818
# validating model model_rawdat_checkpoints/rawmodel_wb_cv7.best.hdf5
# 66/66 [==============================] - 1s 22ms/step
# Test acc: 81.82%
# Distribution of diagnoses in test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# AUC for MCI vs. CN = 0.840
# AUC for AD vs. CN = 0.933
# confusion matrix
# [[22  3]
#  [ 0  0]
#  [ 7 15]
#  [ 2 17]]
# Distribution of diagnoses in training data: [1=CN, 3=LMCI, 4=AD]
# 1    229
# 3    198
# 4    170
# Name: Group, dtype: int64
# [5057, 331, 214, 5067, 5095, 5123, 4971, 5006, 994, 1004, 4001, 4209, 4280, 4282, 4353, 4500, 4718, 4879, 4894, 1155, 6334, 872, 291, 1106, 709, 1246, 6180, 4294, 4394, 4402, 4408, 4426, 4507, 4584, 4611, 4668, 4671, 4712, 4720, 4842, 4852, 751, 4208, 69, 1286, 112, 886, 4028, 4060, 4082, 4200, 4222, 4277, 4386, 4429, 4446, 4449, 4496, 4499, 4520, 4552, 4560, 4578, 4579, 4580, 4795]
# Distribution of diagnoses in holdout test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# Train on 8358 samples, validate on 66 samples
# Epoch 1/20
# 8358/8358 [==============================] - 197s 24ms/step - loss: 1.1051 - acc: 0.5541 - val_loss: 1.0572 - val_acc: 0.5455
#
# Epoch 00001: val_acc improved from -inf to 0.54545, saving model to model_rawdat_checkpoints/rawmodel_wb_cv8-e01-0.55.hdf5
# Epoch 2/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.9171 - acc: 0.6620 - val_loss: 0.7878 - val_acc: 0.7121
#
# Epoch 00002: val_acc improved from 0.54545 to 0.71212, saving model to model_rawdat_checkpoints/rawmodel_wb_cv8-e02-0.71.hdf5
# Epoch 3/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.7874 - acc: 0.7066 - val_loss: 0.6832 - val_acc: 0.7424
#
# Epoch 00003: val_acc improved from 0.71212 to 0.74242, saving model to model_rawdat_checkpoints/rawmodel_wb_cv8-e03-0.74.hdf5
# Epoch 4/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.7022 - acc: 0.7313 - val_loss: 0.6717 - val_acc: 0.7424
#
# Epoch 00004: val_acc improved from 0.74242 to 0.74242, saving model to model_rawdat_checkpoints/rawmodel_wb_cv8-e04-0.74.hdf5
# Epoch 5/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.6414 - acc: 0.7414 - val_loss: 0.6308 - val_acc: 0.7121
#
# Epoch 00005: val_acc did not improve from 0.74242
# Epoch 6/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5950 - acc: 0.7536 - val_loss: 0.7384 - val_acc: 0.6515
#
# Epoch 00006: val_acc did not improve from 0.74242
# Epoch 7/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5520 - acc: 0.7651 - val_loss: 0.6450 - val_acc: 0.7121
#
# Epoch 00007: val_acc did not improve from 0.74242
# Epoch 8/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.5240 - acc: 0.7728 - val_loss: 0.6554 - val_acc: 0.6667
#
# Epoch 00008: val_acc did not improve from 0.74242
# Epoch 9/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4948 - acc: 0.7816 - val_loss: 0.6787 - val_acc: 0.6818
#
# Epoch 00009: val_acc did not improve from 0.74242
# Epoch 10/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4834 - acc: 0.7844 - val_loss: 0.6360 - val_acc: 0.6818
#
# Epoch 00010: val_acc did not improve from 0.74242
# Epoch 11/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4539 - acc: 0.7990 - val_loss: 0.6380 - val_acc: 0.6818
#
# Epoch 00011: val_acc did not improve from 0.74242
# Epoch 12/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.4289 - acc: 0.8122 - val_loss: 0.6518 - val_acc: 0.7121
#
# Epoch 00012: val_acc did not improve from 0.74242
# Epoch 13/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4136 - acc: 0.8169 - val_loss: 0.6819 - val_acc: 0.6515
#
# Epoch 00013: val_acc did not improve from 0.74242
# Epoch 14/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4010 - acc: 0.8218 - val_loss: 0.6905 - val_acc: 0.6970
#
# Epoch 00014: val_acc did not improve from 0.74242
# Epoch 15/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3767 - acc: 0.8329 - val_loss: 0.6883 - val_acc: 0.6364
#
# Epoch 00015: val_acc did not improve from 0.74242
# Epoch 16/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3549 - acc: 0.8486 - val_loss: 0.8168 - val_acc: 0.6515
#
# Epoch 00016: val_acc did not improve from 0.74242
# Epoch 17/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3394 - acc: 0.8573 - val_loss: 0.8175 - val_acc: 0.6515
#
# Epoch 00017: val_acc did not improve from 0.74242
# Epoch 18/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3207 - acc: 0.8618 - val_loss: 0.7983 - val_acc: 0.6515
#
# Epoch 00018: val_acc did not improve from 0.74242
# Epoch 19/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3058 - acc: 0.8684 - val_loss: 0.7006 - val_acc: 0.6364
#
# Epoch 00019: val_acc did not improve from 0.74242
# Epoch 20/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.2831 - acc: 0.8823 - val_loss: 0.8465 - val_acc: 0.6515
#
# Epoch 00020: val_acc did not improve from 0.74242
# validating model model_rawdat_checkpoints/rawmodel_wb_cv8.best.hdf5
# 66/66 [==============================] - 2s 24ms/step
# Test acc: 74.24%
# Distribution of diagnoses in test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# AUC for MCI vs. CN = 0.704
# AUC for AD vs. CN = 0.964
# confusion matrix
# [[18  7]
#  [ 0  0]
#  [10 12]
#  [ 0 19]]
# Distribution of diagnoses in training data: [1=CN, 3=LMCI, 4=AD]
# 1    229
# 3    198
# 4    170
# Name: Group, dtype: int64
# [1057, 5224, 658, 5032, 5120, 5054, 835, 5210, 5208, 1007, 4997, 4192, 4494, 4615, 4676, 4707, 4719, 4801, 4845, 4251, 1074, 4194, 1169, 989, 1187, 4189, 6336, 4057, 4079, 4171, 4354, 4377, 4403, 4531, 4590, 4711, 4807, 4817, 4903, 4909, 4989, 984, 74, 923, 5040, 315, 680, 4198, 4003, 4066, 4104, 4119, 4120, 4139, 4158, 4164, 4266, 4335, 4357, 4384, 4421, 4424, 4453, 4491, 4508, 4688]
# Distribution of diagnoses in holdout test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# Train on 8358 samples, validate on 66 samples
# Epoch 1/20
# 8358/8358 [==============================] - 198s 24ms/step - loss: 1.1213 - acc: 0.5684 - val_loss: 1.1044 - val_acc: 0.5606
#
# Epoch 00001: val_acc improved from -inf to 0.56061, saving model to model_rawdat_checkpoints/rawmodel_wb_cv9-e01-0.56.hdf5
# Epoch 2/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.9669 - acc: 0.6443 - val_loss: 0.9291 - val_acc: 0.6667
#
# Epoch 00002: val_acc improved from 0.56061 to 0.66667, saving model to model_rawdat_checkpoints/rawmodel_wb_cv9-e02-0.67.hdf5
# Epoch 3/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.8550 - acc: 0.6746 - val_loss: 0.8532 - val_acc: 0.6667
#
# Epoch 00003: val_acc improved from 0.66667 to 0.66667, saving model to model_rawdat_checkpoints/rawmodel_wb_cv9-e03-0.67.hdf5
# Epoch 4/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.7638 - acc: 0.6993 - val_loss: 0.7002 - val_acc: 0.7879
#
# Epoch 00004: val_acc improved from 0.66667 to 0.78788, saving model to model_rawdat_checkpoints/rawmodel_wb_cv9-e04-0.79.hdf5
# Epoch 5/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.6866 - acc: 0.7172 - val_loss: 0.7057 - val_acc: 0.6818
#
# Epoch 00005: val_acc did not improve from 0.78788
# Epoch 6/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.6193 - acc: 0.7414 - val_loss: 0.6027 - val_acc: 0.8030
#
# Epoch 00006: val_acc improved from 0.78788 to 0.80303, saving model to model_rawdat_checkpoints/rawmodel_wb_cv9-e06-0.80.hdf5
# Epoch 7/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5758 - acc: 0.7522 - val_loss: 0.5691 - val_acc: 0.7576
#
# Epoch 00007: val_acc did not improve from 0.80303
# Epoch 8/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5413 - acc: 0.7635 - val_loss: 0.5552 - val_acc: 0.7576
#
# Epoch 00008: val_acc did not improve from 0.80303
# Epoch 9/20
# 8358/8358 [==============================] - 193s 23ms/step - loss: 0.5106 - acc: 0.7729 - val_loss: 0.6048 - val_acc: 0.7576
#
# Epoch 00009: val_acc did not improve from 0.80303
# Epoch 10/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4840 - acc: 0.7794 - val_loss: 0.6321 - val_acc: 0.7273
#
# Epoch 00010: val_acc did not improve from 0.80303
# Epoch 11/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4616 - acc: 0.7931 - val_loss: 0.6352 - val_acc: 0.7273
#
# Epoch 00011: val_acc did not improve from 0.80303
# Epoch 12/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4323 - acc: 0.8082 - val_loss: 0.5623 - val_acc: 0.7879
#
# Epoch 00012: val_acc did not improve from 0.80303
# Epoch 13/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4075 - acc: 0.8180 - val_loss: 0.6766 - val_acc: 0.7273
#
# Epoch 00013: val_acc did not improve from 0.80303
# Epoch 14/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3846 - acc: 0.8307 - val_loss: 0.6855 - val_acc: 0.7273
#
# Epoch 00014: val_acc did not improve from 0.80303
# Epoch 15/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3682 - acc: 0.8367 - val_loss: 0.6150 - val_acc: 0.6970
#
# Epoch 00015: val_acc did not improve from 0.80303
# Epoch 16/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.3400 - acc: 0.8516 - val_loss: 0.6971 - val_acc: 0.6970
#
# Epoch 00016: val_acc did not improve from 0.80303
# Epoch 17/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.3211 - acc: 0.8659 - val_loss: 0.6091 - val_acc: 0.7121
#
# Epoch 00017: val_acc did not improve from 0.80303
# Epoch 18/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.3062 - acc: 0.8702 - val_loss: 0.6930 - val_acc: 0.6818
#
# Epoch 00018: val_acc did not improve from 0.80303
# Epoch 19/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.2761 - acc: 0.8906 - val_loss: 0.6287 - val_acc: 0.6970
#
# Epoch 00019: val_acc did not improve from 0.80303
# Epoch 20/20
# 8358/8358 [==============================] - 191s 23ms/step - loss: 0.2605 - acc: 0.8989 - val_loss: 1.1367 - val_acc: 0.6970
#
# Epoch 00020: val_acc did not improve from 0.80303
# validating model model_rawdat_checkpoints/rawmodel_wb_cv9.best.hdf5
# 66/66 [==============================] - 2s 26ms/step
# Test acc: 80.30%
# Distribution of diagnoses in test data: [1=CN, 3=LMCI, 4=AD]
# 1    25
# 3    22
# 4    19
# Name: Group, dtype: int64
# AUC for MCI vs. CN = 0.689
# AUC for AD vs. CN = 0.947
# confusion matrix
# [[21  4]
#  [ 0  0]
#  [ 8 14]
#  [ 1 18]]
# Distribution of diagnoses in training data: [1=CN, 3=LMCI, 4=AD]
# 1    228
# 3    198
# 4    171
# Name: Group, dtype: int64
# [729, 4924, 5205, 5016, 160, 361, 227, 4172, 4211, 4338, 4501, 4625, 4728, 4756, 4802, 4853, 4949, 5018, 698, 4302, 285, 1378, 4187, 4096, 4114, 4162, 4456, 4462, 4489, 4538, 4548, 4631, 4653, 4675, 4715, 4806, 4869, 4892, 4902, 4918, 23, 1352, 47, 295, 311, 4018, 4020, 4081, 4150, 4176, 4254, 4279, 4291, 4339, 4387, 4389, 4427, 4428, 4433, 4448, 4466, 4506, 4586, 4587, 4632, 4739]
# Distribution of diagnoses in holdout test data: [1=CN, 3=LMCI, 4=AD]
# 1    26
# 3    22
# 4    18
# Name: Group, dtype: int64
# Train on 8358 samples, validate on 66 samples
# Epoch 1/20
# 8358/8358 [==============================] - 197s 24ms/step - loss: 1.1352 - acc: 0.5492 - val_loss: 1.0746 - val_acc: 0.5000
#
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to model_rawdat_checkpoints/rawmodel_wb_cv10-e01-0.50.hdf5
# Epoch 2/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.9701 - acc: 0.6341 - val_loss: 0.9452 - val_acc: 0.5758
#
# Epoch 00002: val_acc improved from 0.50000 to 0.57576, saving model to model_rawdat_checkpoints/rawmodel_wb_cv10-e02-0.58.hdf5
# Epoch 3/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.8551 - acc: 0.6832 - val_loss: 0.8943 - val_acc: 0.6212
#
# Epoch 00003: val_acc improved from 0.57576 to 0.62121, saving model to model_rawdat_checkpoints/rawmodel_wb_cv10-e03-0.62.hdf5
# Epoch 4/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.7570 - acc: 0.7212 - val_loss: 0.8182 - val_acc: 0.5758
#
# Epoch 00004: val_acc did not improve from 0.62121
# Epoch 5/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.6874 - acc: 0.7370 - val_loss: 0.7560 - val_acc: 0.6212
#
# Epoch 00005: val_acc improved from 0.62121 to 0.62121, saving model to model_rawdat_checkpoints/rawmodel_wb_cv10-e05-0.62.hdf5
# Epoch 6/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.6289 - acc: 0.7515 - val_loss: 0.7914 - val_acc: 0.6212
#
# Epoch 00006: val_acc improved from 0.62121 to 0.62121, saving model to model_rawdat_checkpoints/rawmodel_wb_cv10-e06-0.62.hdf5
# Epoch 7/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5712 - acc: 0.7766 - val_loss: 0.6856 - val_acc: 0.6667
#
# Epoch 00007: val_acc improved from 0.62121 to 0.66667, saving model to model_rawdat_checkpoints/rawmodel_wb_cv10-e07-0.67.hdf5
# Epoch 8/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.5295 - acc: 0.7837 - val_loss: 0.7339 - val_acc: 0.6515
#
# Epoch 00008: val_acc did not improve from 0.66667
# Epoch 9/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4923 - acc: 0.8007 - val_loss: 0.6479 - val_acc: 0.6364
#
# Epoch 00009: val_acc did not improve from 0.66667
# Epoch 10/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4428 - acc: 0.8221 - val_loss: 0.6571 - val_acc: 0.6364
#
# Epoch 00010: val_acc did not improve from 0.66667
# Epoch 11/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.4145 - acc: 0.8356 - val_loss: 0.6363 - val_acc: 0.6667
#
# Epoch 00011: val_acc did not improve from 0.66667
# Epoch 12/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3785 - acc: 0.8550 - val_loss: 0.6712 - val_acc: 0.6818
#
# Epoch 00012: val_acc improved from 0.66667 to 0.68182, saving model to model_rawdat_checkpoints/rawmodel_wb_cv10-e12-0.68.hdf5
# Epoch 13/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3348 - acc: 0.8747 - val_loss: 0.6281 - val_acc: 0.7121
#
# Epoch 00013: val_acc improved from 0.68182 to 0.71212, saving model to model_rawdat_checkpoints/rawmodel_wb_cv10-e13-0.71.hdf5
# Epoch 14/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.3007 - acc: 0.8934 - val_loss: 0.7327 - val_acc: 0.7424
#
# Epoch 00014: val_acc improved from 0.71212 to 0.74242, saving model to model_rawdat_checkpoints/rawmodel_wb_cv10-e14-0.74.hdf5
# Epoch 15/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.2661 - acc: 0.9072 - val_loss: 0.6695 - val_acc: 0.7121
#
# Epoch 00015: val_acc did not improve from 0.74242
# Epoch 16/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.2430 - acc: 0.9176 - val_loss: 0.7012 - val_acc: 0.6970
#
# Epoch 00016: val_acc did not improve from 0.74242
# Epoch 17/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.2134 - acc: 0.9312 - val_loss: 0.8362 - val_acc: 0.6667
#
# Epoch 00017: val_acc did not improve from 0.74242
# Epoch 18/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.1986 - acc: 0.9383 - val_loss: 0.8563 - val_acc: 0.7424
#
# Epoch 00018: val_acc did not improve from 0.74242
# Epoch 19/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.1731 - acc: 0.9536 - val_loss: 0.7400 - val_acc: 0.6818
#
# Epoch 00019: val_acc did not improve from 0.74242
# Epoch 20/20
# 8358/8358 [==============================] - 192s 23ms/step - loss: 0.1521 - acc: 0.9628 - val_loss: 0.7879 - val_acc: 0.6970
#
# Epoch 00020: val_acc did not improve from 0.74242
# validating model model_rawdat_checkpoints/rawmodel_wb_cv10.best.hdf5
# 66/66 [==============================] - 2s 29ms/step
# Test acc: 74.24%
# Distribution of diagnoses in test data: [1=CN, 3=LMCI, 4=AD]
# 1    26
# 3    22
# 4    18
# Name: Group, dtype: int64
# AUC for MCI vs. CN = 0.729
# AUC for AD vs. CN = 0.885
# confusion matrix
# [[13 13]
#  [ 0  0]
#  [ 3 19]
#  [ 1 17]]

# %%
# print model performance summary
from statistics import mean,stdev

print('Mean AUC for MCI vs. CN = %0.3f +/- %0.3f' % (mean(auc_MCI), stdev(auc_MCI)))
print('Mean AUC for AD vs. CN = %0.3f +/- %0.3f' % (mean(auc_AD), stdev(auc_AD)))

print('Mean Acc for MCI vs. CN = %0.3f +/- %0.3f' % (mean(sen_MCI), stdev(acc_MCI)))
print('Mean Acc for AD vs. CN = %0.3f +/- %0.3f' % (mean(sen_AD), stdev(acc_AD)))

print('Mean Bacc for MCI vs. CN = %0.3f +/- %0.3f' % (mean(bacc_MCI), stdev(bacc_MCI)))
print('Mean Bacc for AD vs. CN = %0.3f +/- %0.3f' % (mean(bacc_AD), stdev(bacc_AD)))

print('Mean Sen for MCI vs. CN = %0.3f +/- %0.3f' % (mean(sen_MCI), stdev(sen_MCI)))
print('Mean Sen for AD vs. CN = %0.3f +/- %0.3f' % (mean(sen_AD), stdev(sen_AD)))

print('Mean Spec for MCI vs. CN = %0.3f +/- %0.3f' % (mean(spec_MCI), stdev(spec_MCI)))
print('Mean Spec for AD vs. CN = %0.3f +/- %0.3f' % (mean(spec_AD), stdev(spec_AD)))

print('Mean PPV for MCI vs. CN = %0.3f +/- %0.3f' % (mean(ppv_MCI), stdev(ppv_MCI)))
print('Mean PPV for AD vs. CN = %0.3f +/- %0.3f' % (mean(ppv_AD), stdev(ppv_AD)))

print('Mean NPV for MCI vs. CN = %0.3f +/- %0.3f' % (mean(npv_MCI), stdev(npv_MCI)))
print('Mean NPV for AD vs. CN = %0.3f +/- %0.3f' % (mean(npv_AD), stdev(npv_AD)))

print('Mean F1 for MCI vs. CN = %0.3f +/- %0.3f' % (mean(f1_MCI), stdev(f1_MCI)))
print('Mean F1 for AD vs. CN = %0.3f +/- %0.3f' % (mean(f1_AD), stdev(f1_AD)))
# Out:
# Mean AUC for MCI vs. CN = 0.731 +/- 0.070
# Mean AUC for AD vs. CN = 0.921 +/- 0.024
# Mean Acc for MCI vs. CN = 0.650 +/- 5.981
# Mean Acc for AD vs. CN = 0.921 +/- 7.861
# Mean Bacc for MCI vs. CN = 0.711 +/- 0.057
# Mean Bacc for AD vs. CN = 0.846 +/- 0.065
# Mean Sen for MCI vs. CN = 0.650 +/- 0.129
# Mean Sen for AD vs. CN = 0.921 +/- 0.045
# Mean Spec for MCI vs. CN = 0.771 +/- 0.151
# Mean Spec for AD vs. CN = 0.771 +/- 0.151
# Mean PPV for MCI vs. CN = 0.734 +/- 0.100
# Mean PPV for AD vs. CN = 0.768 +/- 0.110
# Mean NPV for MCI vs. CN = 0.724 +/- 0.058
# Mean NPV for AD vs. CN = 0.931 +/- 0.031
# Mean F1 for MCI vs. CN = 0.676 +/- 0.068
# Mean F1 for AD vs. CN = 0.831 +/- 0.061

# %%
results = pd.DataFrame({'AUC_MCI':auc_MCI, 'Acc_MCI':acc_MCI, 'Bacc_MCI':bacc_MCI, 'f1_MCI':f1_MCI,
                        'sen_MCI':sen_MCI, 'spec_MCI':spec_MCI, 'ppv_MCI':ppv_MCI, 'npv_MCI':npv_MCI,
                        'AUC_AD':auc_AD, 'Acc_AD':acc_AD, 'Bacc_AD':bacc_AD, 'f1_AD':f1_AD,
                        'sen_AD':sen_AD, 'spec_AD':spec_AD, 'ppv_AD':ppv_AD, 'npv_AD':npv_AD})
print(results)
results.to_csv('results_rawdat_xval_ADNI2_checkpoints.csv')
# Out:
#     AUC_MCI    Acc_MCI  Bacc_MCI    f1_MCI   sen_MCI  spec_MCI   ppv_MCI  \
# 0  0.732517  72.916667  0.711538  0.628571  0.500000  0.923077  0.846154
# 1  0.807692  75.000000  0.737762  0.684211  0.590909  0.884615  0.812500
# 2  0.624126  68.750000  0.669580  0.571429  0.454545  0.884615  0.769231
# 3  0.758182  74.468085  0.743636  0.727273  0.727273  0.760000  0.727273
# 4  0.640000  61.702128  0.623636  0.640000  0.727273  0.520000  0.571429
# 5  0.787273  78.723404  0.786364  0.772727  0.772727  0.800000  0.772727
# 6  0.840000  78.723404  0.780909  0.750000  0.681818  0.880000  0.833333
# 7  0.703636  63.829787  0.632727  0.585366  0.545455  0.720000  0.631579
# 8  0.689091  74.468085  0.738182  0.700000  0.636364  0.840000  0.777778
# 9  0.729021  66.666667  0.681818  0.703704  0.863636  0.500000  0.593750
#
#     npv_MCI    AUC_AD     Acc_AD   Bacc_AD     f1_AD    sen_AD   spec_AD  \
# 0  0.685714  0.921053  88.888889  0.882591  0.864865  0.842105  0.923077
# 1  0.718750  0.910931  88.888889  0.889676  0.871795  0.894737  0.884615
# 2  0.657143  0.917004  88.888889  0.889676  0.871795  0.894737  0.884615
# 3  0.760000  0.928421  81.818182  0.827368  0.809524  0.894737  0.760000
# 4  0.684211  0.888421  70.454545  0.733684  0.734694  0.947368  0.520000
# 5  0.800000  0.917895  86.363636  0.873684  0.857143  0.947368  0.800000
# 6  0.758621  0.932632  88.636364  0.887368  0.871795  0.894737  0.880000
# 7  0.642857  0.964211  84.090909  0.860000  0.844444  1.000000  0.720000
# 8  0.724138  0.947368  88.636364  0.893684  0.878049  0.947368  0.840000
# 9  0.812500  0.884615  68.181818  0.722222  0.708333  0.944444  0.500000
#
#      ppv_AD    npv_AD
# 0  0.888889  0.888889
# 1  0.850000  0.920000
# 2  0.850000  0.920000
# 3  0.739130  0.904762
# 4  0.600000  0.928571
# 5  0.782609  0.952381
# 6  0.850000  0.916667
# 7  0.730769  1.000000
# 8  0.818182  0.954545
# 9  0.566667  0.928571
