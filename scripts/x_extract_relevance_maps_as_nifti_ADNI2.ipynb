# %%
# Import data from Excel sheet
import pandas as pd
df = pd.read_excel('/data_dzne_archiv2/Studien/Deep_Learning_Visualization/data/hippocampus_volume_relevance_ADNI2.xlsx', sheet_name='ADNI2_LRP_CMP')
#print(df)
sid = df['subject_ID']
grp = df['Group at scan date (1=CN, 2=EMCI, 3=LMCI, 4=AD, 5=SMC)']
age = df['Age at scan']
sex = df['Sex (1=female)']
tiv = df['TIV_CAT12']
field = df['MRI_Field_Strength']
amybin = df['Amy SUVR Pos']
grpbin = (grp > 1) # 1=CN, ...

# %%
# Scan for nifti file names
import glob
dataAD = sorted(glob.glob('/data_dzne_archiv2/Studien/Deep_Learning_Visualization/data/mwp1_MNI_ADNI/AD/*.nii.gz'))
dataLMCI = sorted(glob.glob('/data_dzne_archiv2/Studien/Deep_Learning_Visualization/data/mwp1_MNI_ADNI/LMCI/*.nii.gz'))
dataCN = sorted(glob.glob('/data_dzne_archiv2/Studien/Deep_Learning_Visualization/data/mwp1_MNI_ADNI/CN/*.nii.gz'))
dataFiles = dataAD + dataLMCI + dataCN
numfiles = len(dataFiles)
print('Found ', str(numfiles), ' nifti files')
# Out:
# Found  663  nifti files

# %%
import re
import numpy as np
from keras.utils import to_categorical
debug = False
cov_idx = [-1] * numfiles # list; array: np.full((numfiles, 1), -1, dtype=int)
print('Matching covariates for loaded files ...')
for i,id in enumerate(sid):
    p = [j for j,x in enumerate(dataFiles) if re.search('_%04d_' % id, x)] # translate ID numbers to four-digit numbers, get both index and filename
    if len(p)==0:
        if debug: print('Did not find %04d' % id) # did not find Excel sheet subject ID in loaded file selection
    else:
        if debug: print('Found %04d in %s: %s' % (id, p[0], dataFiles[p[0]]))
        cov_idx[p[0]] = i # store Excel index i for data file index p[0]
print('Checking for scans not found in Excel sheet: ', sum(x<0 for x in cov_idx))

labels = pd.DataFrame({'Group':grpbin}).iloc[cov_idx, :]
labels = to_categorical(np.asarray(labels)) # use grps to access original labels
grps = pd.DataFrame({'Group':grp, 'RID':sid}).iloc[cov_idx, :]
# Out:
# Using TensorFlow backend.
# Matching covariates for loaded files ...
# Checking for scans not found in Excel sheet:  0

# %%
#Load residualized data from disk
import h5py
hf = h5py.File('residuals_ADNI2_wb_mwp1_CAT12_MNI.hdf5', 'r')
hf.keys # read keys
images = np.array(hf.get('images'))
hf.close()

# %%
import tensorflow as tf
print(tf.__version__)

# disable tensorflow deprecation warnings
import logging
logging.getLogger('tensorflow').disabled=True

from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto(
    gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=1)
    # device_count = {'GPU': 1}
)
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
set_session(session)
# Out:
# 1.15.5
# 2023-12-01 09:34:26.126259: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-01 09:34:26.137640: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3192500000 Hz
# 2023-12-01 09:34:26.138352: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xbe9bc80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-01 09:34:26.138376: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-01 09:34:26.141293: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-01 09:34:26.265739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-01 09:34:26.265991: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xbae48b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-01 09:34:26.266016: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 6000, Compute Capability 7.5
# 2023-12-01 09:34:26.266252: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-01 09:34:26.266385: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Quadro RTX 6000 major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:0b:00.0
# 2023-12-01 09:34:26.266660: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-01 09:34:26.268011: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-01 09:34:26.269208: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-12-01 09:34:26.269521: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-12-01 09:34:26.271090: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-12-01 09:34:26.272259: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2023-12-01 09:34:26.276447: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-01 09:34:26.276605: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-01 09:34:26.276809: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-01 09:34:26.276903: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2023-12-01 09:34:26.276973: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-01 09:34:26.277251: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-01 09:34:26.277267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2023-12-01 09:34:26.277271: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2023-12-01 09:34:26.277386: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-01 09:34:26.277521: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-01 09:34:26.277654: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 24212 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:0b:00.0, compute capability: 7.5)

# %%
import nibabel as nib

# define FOV to reduce required memory size
x_range_from = 10; x_range_to = 110
y_range_from = 13; y_range_to = 133
z_range_from = 5; z_range_to = 105

data_overlay = sorted(glob.glob('Hippocampus_masks/aal_hippocampus.nii*'))

# %%
# Load CNN model from disk --> save predictions
from keras.models import load_model

batch_size = 20

for k in [0]: #range(20):
    mymodel = load_model('model_checkpoints/resmodel_wb_whole_ds.hdf5') #load_model('model_checkpoints/resmodel_wb_cv%d.best.hdf5' % (k+1))
    #mymodel.summary()
    pred = mymodel.predict(images, batch_size=batch_size)
    # only output prediction scores for AD output neuron
    results = pd.DataFrame({'SID':grps.RID, 'Group':grps.Group, 'pred':pred[:,1]})
    results.to_csv('results_wholeds_ADNI2_predictions.csv')
# Out:
# 2023-12-01 09:34:28.796267: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-01 09:34:29.077898: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-01 09:34:30.109895: W tensorflow/stream_executor/cuda/redzone_allocator.cc:312] Not found: ./bin/ptxas not found
# Relying on driver to perform ptx compilation. This message will be only logged once.

# %%
# Load CNN model from disk
from keras.models import load_model, Model
#!pip install innvestigate
import innvestigate
import innvestigate.utils as iutils
import numpy as np
from matplotlib import pyplot as plt
import scipy
import csv


# see https://github.com/albermax/innvestigate/blob/master/examples/notebooks/imagenet_compare_methods.ipynb for a list of alternative methods
methods = [ # tuple with method,     params,                  label
#            ("deconvnet",            {},                      "Deconvnet"),
#            ("guided_backprop",      {},                      "Guided Backprop"),
#            ("deep_taylor.bounded",  {"low": -1, "high": 1},  "DeepTaylor"),
#            ("input_t_gradient",     {},                      "Input * Gradient"),
#            ("lrp.z",                {},                      "LRP-Z"),
#            ("lrp.epsilon",          {"epsilon": 1},          "LRP-epsilon"),
#            ("lrp.alpha_1_beta_0",   {"neuron_selection_mode":"index"},     "LRP-alpha1beta0"),
        ("lrp.sequential_preset_a", {"neuron_selection_mode": "index", "epsilon": 1e-10}, "LRP-CMPalpha1beta0"), # LRP CMP rule taken from https://github.com/berleon/when-explanations-lie/blob/master/when_explanations_lie.py
]

hipp_nifti = nib.load(data_overlay[0])  # assume it is already 32bit float format
new_data = np.zeros((121, 145, 121), dtype=np.float32) 

for k in [0]: #range(20):
    mymodel = load_model('model_checkpoints/resmodel_wb_whole_ds.hdf5') #load_model('model_checkpoints/resmodel_wb_cv%d.best.hdf5' % (k+1))
    #mymodel.summary()
    #model_wo_softmax = iutils.keras.graph.model_wo_softmax(mymodel)  ## sometimes raises: ValueError: The name "dense_1" is used 2 times in the model. All layer names should be unique.
    #model_wo_softmax = Model(inputs=mymodel.inputs,
    #                          outputs=iutils.keras.graph.pre_softmax_tensors(mymodel.outputs),
    #                          name=(mymodel.name + '_wo_softmax')) 
    #model_wo_softmax.summary()
    mymodel.layers[-1].activation=tf.keras.activations.linear
    mymodel.save('tmp_wo_softmax.hdf5')
    model_wo_softmax = load_model('tmp_wo_softmax.hdf5')
    if (k==0):
        model_wo_softmax.summary()

    # create analyzer
    analyzers = []
    for method in methods:
        #analyzer = innvestigate.create_analyzer("deep_taylor.bounded", model_wo_softmax, **params )
        analyzer = innvestigate.create_analyzer(method[0], model_wo_softmax, **method[1])
        # Some analyzers require training.
        #   analyzer.fit(test_img, batch_size=30, verbose=1)
        #  analyzers.append(analyzer)
     
    for indx in range(len(grps)):
        test_img = images[indx]
        #test_orig = images_orig[indx]
        #print('test image for subject of binary group: %d' % test_Y[subj_idx, 1]) # first col will indicate CN, second col indicates MCI/AD
        #print('test image for subject of ADNI diagnosis: %d [1-CN, 3-LMCI, 4-AD]' % testgrps.Group.to_numpy(dtype=np.int)[subj_idx])

        ####print('test subject ID %s' % grps.RID.to_numpy(dtype=np.int)[indx])

        test_img = np.reshape(test_img, (1,)+ test_img.shape) # add first subj index again to mimic original array structure
        #test_orig = np.reshape(test_orig, (1,)+ test_orig.shape) # add first subj index again to mimic original array structure

        #for method,analyzer in zip(methods, analyzers):
        a = np.reshape(analyzer.analyze(test_img, neuron_selection=1), test_img.shape[1:4])
        #np.clip(a, a_min=0, a_max=None, out=a)
        #a = scipy.ndimage.filters.gaussian_filter(a, sigma=0.8) # smooth activity image
        #scale = np.quantile(a, 0.99) # no need for abs(a)
        #if scale!=0:  # ignore if relevance maps contains only zeros, output will be zero as well
        #    a = (a/scale)

        a = np.flip(a) # flip all positions
        a = np.transpose(a, (1, 2, 0)) # reorder dimensions from coronal view z*x*y back to x*y*z

        print('saving lrp_maps_ADNI2/lrp_map_grp%d_%04d_whole_ds_model.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx])) #'saving lrp_map_grp%d_%04d_cv%d.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx], (k+1)))
        new_data[x_range_from:x_range_to, y_range_from:y_range_to, z_range_from:z_range_to] = a
        nifti = nib.Nifti1Image(new_data, hipp_nifti.affine, hipp_nifti.header)
        nifti.to_filename('lrp_maps_ADNI2/lrp_map_grp%d_%04d_whole_ds_model.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx])) #'lrp_map_grp%d_%04d_cv%d.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx], (k+1)))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 100, 100, 120, 5)  140
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 50, 50, 60, 5)     0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 60, 5)     20
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 50, 50, 60, 5)     680
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 25, 25, 30, 5)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 30, 5)     20
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 25, 25, 30, 5)     680
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 12, 12, 15, 5)     0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 15, 5)     20
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10800)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10800)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                691264
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 694,970
# Trainable params: 694,940
# Non-trainable params: 30
# _________________________________________________________________
# saving lrp_maps_ADNI2/lrp_map_grp4_0729_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1057_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5165_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5187_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0572_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5038_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5119_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1130_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0101_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5196_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1030_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5027_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5037_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5224_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5252_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_6303_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5071_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0658_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0702_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1117_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1326_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5032_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5057_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5251_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5240_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4924_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0042_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0331_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0376_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0887_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5120_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5241_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5054_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0408_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0835_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4964_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0830_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0214_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0906_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5013_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5017_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5087_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0292_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0997_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5063_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5112_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5210_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0552_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5162_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1010_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1425_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4980_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5005_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1346_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4959_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5062_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5070_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5208_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1007_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5205_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4859_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4968_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5146_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5016_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5090_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5029_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5184_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0160_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0269_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0667_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0051_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4994_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5106_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0166_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0378_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_6039_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0361_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1427_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4992_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5028_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5056_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5058_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5067_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5095_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0135_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0227_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0230_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1043_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5123_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4971_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4990_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4997_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5006_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5059_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5231_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5138_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5015_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5275_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0873_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0973_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_0994_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1004_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_1255_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_6142_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4001_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4009_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4024_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4039_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4089_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4136_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4152_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4153_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4172_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4192_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4195_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4201_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4209_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4211_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4215_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4223_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4252_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4258_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4280_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4282_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4307_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4338_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4353_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4373_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4379_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4477_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4494_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4500_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4501_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4526_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4546_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4549_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4568_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4583_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4589_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4591_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4615_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4625_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4641_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4657_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4660_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4672_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4676_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4686_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4692_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4696_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4707_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4718_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4719_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4728_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4730_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4732_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4737_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4755_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4756_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4770_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4772_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4774_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4783_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4792_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4801_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4802_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4820_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4827_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4845_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4853_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4863_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4867_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4879_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4887_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4894_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4905_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4906_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4910_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4911_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4912_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4940_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4949_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4954_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4962_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4982_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_4984_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5012_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5018_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp4_5019_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1155_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4229_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4251_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0908_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1074_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1122_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_6258_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0546_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_6427_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0698_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4543_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0420_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_6073_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4985_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0142_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4922_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1046_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4115_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_6334_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_6356_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1063_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0307_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0644_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1045_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4729_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4804_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1218_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1318_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0867_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4194_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4203_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1169_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4714_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4899_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0150_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0454_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4302_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0679_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1418_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1072_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0671_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0989_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4945_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0919_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1269_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0872_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1380_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0746_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4300_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4311_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4630_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0291_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0296_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1226_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1106_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1118_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_5047_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4167_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1300_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0709_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1187_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0925_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1419_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4928_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0200_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1408_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0778_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1246_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0285_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0505_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4250_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4542_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0123_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0107_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4189_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0800_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1414_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_0717_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1052_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1378_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_6274_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_6336_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_6180_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_6056_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_6297_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4187_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1186_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_1268_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4015_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4029_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4030_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4034_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4035_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4042_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4053_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4057_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4058_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4061_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4077_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4079_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4094_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4096_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4114_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4122_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4131_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4138_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4162_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4169_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4170_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4171_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4197_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4210_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4214_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4219_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4240_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4243_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4244_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4263_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4287_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4293_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4294_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4303_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4324_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4346_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4354_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4359_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4363_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4366_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4377_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4381_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4394_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4395_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4402_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4403_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4406_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4408_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4414_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4426_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4430_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4444_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4456_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4458_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4462_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4489_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4502_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4507_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4510_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4515_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4521_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4524_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4531_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4538_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4548_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4562_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4582_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4584_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4590_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4595_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4596_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4605_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4611_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4626_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4629_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4631_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4636_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4646_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4653_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4654_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4668_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4671_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4675_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4689_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4711_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4712_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4713_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4715_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4720_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4721_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4722_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4723_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4736_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4741_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4743_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4746_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4750_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4757_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4767_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4769_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4777_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4782_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4784_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4793_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4806_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4807_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4815_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4817_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4842_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4852_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4857_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4869_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4873_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4877_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4885_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4888_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4889_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4892_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4896_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4902_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4903_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4904_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4909_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4918_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4925_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4929_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4936_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4943_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4955_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4960_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4976_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp3_4989_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4213_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4270_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0907_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0981_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4872_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0553_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0610_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0498_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_1206_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0751_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0842_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0419_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0023_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4105_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4097_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0159_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0984_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0096_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0130_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0031_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0058_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0061_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0926_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_1190_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0985_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0074_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0120_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0618_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0479_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0734_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0741_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0920_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0923_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_1016_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_1098_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_1352_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0934_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0056_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0059_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0257_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0210_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_5040_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0315_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_5023_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4208_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4234_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0171_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0172_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0896_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4050_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0352_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0047_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0069_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_1286_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0173_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0657_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_1232_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0113_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0680_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0112_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0260_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4198_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0229_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0272_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0545_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0863_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0886_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0969_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0186_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0301_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0668_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0722_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0767_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_6051_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4255_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0021_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0089_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0295_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0311_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_0413_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_1195_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_1202_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_1261_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_1280_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4003_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4010_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4014_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4018_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4020_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4021_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4026_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4028_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4032_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4037_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4041_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4043_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4060_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4066_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4075_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4076_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4080_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4081_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4082_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4084_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4086_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4090_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4092_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4093_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4100_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4103_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4104_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4119_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4120_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4121_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4125_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4139_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4148_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4150_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4151_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4155_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4158_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4164_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4173_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4174_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4176_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4177_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4179_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4196_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4200_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4218_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4222_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4224_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4225_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4254_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4262_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4266_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4269_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4275_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4276_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4277_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4278_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4279_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4288_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4290_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4291_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4292_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4308_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4313_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4320_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4335_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4337_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4339_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4340_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4343_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4345_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4348_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4349_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4350_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4352_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4357_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4365_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4367_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4369_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4371_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4372_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4376_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4382_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4384_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4385_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4386_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4387_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4388_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4389_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4391_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4393_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4396_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4399_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4400_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4401_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4410_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4421_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4422_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4424_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4427_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4428_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4429_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4433_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4441_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4446_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4448_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4449_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4453_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4464_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4466_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4469_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4474_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4482_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4483_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4485_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4488_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4491_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4496_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4499_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4503_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4505_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4506_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4508_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4516_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4520_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4545_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4552_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4555_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4558_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4559_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4560_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4566_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4576_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4577_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4578_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4579_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4580_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4585_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4586_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4587_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4598_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4599_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4604_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4607_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4609_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4612_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4616_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4620_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4632_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4637_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4638_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4643_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4644_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4645_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4649_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4652_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4688_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4739_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4762_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4795_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4832_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4835_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4843_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4855_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4856_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4878_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4900_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4921_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4951_whole_ds_model.nii
# saving lrp_maps_ADNI2/lrp_map_grp1_4952_whole_ds_model.nii
