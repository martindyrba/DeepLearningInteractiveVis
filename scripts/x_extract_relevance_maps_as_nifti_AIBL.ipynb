# %%
# Import data from Excel sheet
import pandas as pd
df = pd.read_excel('/data_dzne_archiv2/Studien/Deep_Learning_Visualization/data/aibl_ptdemog_final.xlsx', sheet_name='aibl_ptdemog_final')
#print(df)
sid = df['RID']
grp = df['DXCURREN']
age = df['age']
sex = df['PTGENDER(1=Female)']
tiv = df['Total'] # TIV
field = df['field_strength']
grpbin = (grp > 1) # 1=CN, ...

# %%
# Scan for nifti file names
import glob
dataAIBL = sorted(glob.glob('/data_dzne_archiv2/Studien/Deep_Learning_Visualization/data/mwp1_MNI_AIBL/*.nii.gz'))
dataFiles = dataAIBL
numfiles = len(dataFiles)
print('Found ', str(numfiles), ' nifti files')
# Out:
# Found  606  nifti files

# %%
# Match covariate information
import re
import numpy as np
from pandas import DataFrame
from keras.utils import to_categorical
debug = False
cov_idx = [-1] * numfiles # list; array: np.full((numfiles, 1), -1, dtype=int)
print('Matching covariates for loaded files ...')
for i,id in enumerate(sid):
  p = [j for j,x in enumerate(dataFiles) if re.search('_%d_MR_' % id, x)] # extract ID numbers from filename, translate to Excel row index
  if len(p)==0:
    if debug: print('Did not find %04d' % id) # did not find Excel sheet subject ID in loaded file selection
  else:
    if debug: print('Found %04d in %s: %s' % (id, p[0], dataFiles[p[0]]))
    cov_idx[p[0]] = i # store Excel index i for data file index p[0]
print('Checking for scans not found in Excel sheet: ', sum(x<0 for x in cov_idx))

labels = pd.DataFrame({'Group':grpbin}).iloc[cov_idx, :]
labels = to_categorical(np.asarray(labels)) # use grps to access original labels
grps = pd.DataFrame({'Group':grp, 'RID':sid}).iloc[cov_idx, :]
# Out:
# Using TensorFlow backend.
# Matching covariates for loaded files ...
# Checking for scans not found in Excel sheet:  0

# %%
# Load residualized data from disk
import h5py
hf = h5py.File('residuals_AIBL_wb_mwp1_CAT12_MNI.hdf5', 'r')
hf.keys # read keys
images = np.array(hf.get('images'))
hf.close()
print(images.shape)
# Out:
# (606, 100, 100, 120, 1)

# %%
# specify version of tensorflow
#%tensorflow_version 1.x
#%tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
# disable tensorflow deprecation warnings
import logging
logging.getLogger('tensorflow').disabled=True
# downgrade to specific version
#!pip install tensorflow-gpu==1.15
#import tensorflow as tf
#print(tf.__version__)
#from keras.backend.tensorflow_backend import set_session
#config = tf.ConfigProto(
#    gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.8)
#    # device_count = {'GPU': 1}
#)
#config.gpu_options.allow_growth = False #True
#session = tf.Session(config=config)
#set_session(session)
# Out:
# 1.15.5

# %%
import nibabel as nib

# define FOV to reduce required memory size
x_range_from = 10; x_range_to = 110
y_range_from = 13; y_range_to = 133
z_range_from = 5; z_range_to = 105

data_overlay = sorted(glob.glob('Hippocampus_masks/aal_hippocampus.nii*'))

# %%
# Load CNN model from disk --> save predictions
from keras.models import load_model

batch_size = 20

for k in [0]: #range(20):
    mymodel = load_model('model_checkpoints/resmodel_wb_whole_ds.hdf5') #load_model('model_checkpoints/resmodel_wb_cv%d.best.hdf5' % (k+1))
    #mymodel.summary()
    pred = mymodel.predict(images, batch_size=batch_size)
    # only output prediction scores for AD output neuron
    results = pd.DataFrame({'SID':grps.RID, 'Group':grps.Group, 'pred':pred[:,1]})
    results.to_csv('results_wholeds_AIBL_predictions.csv')

# %%
# Load CNN model from disk
from keras.models import load_model, Model
#!pip install innvestigate
import innvestigate
import innvestigate.utils as iutils
import numpy as np
from matplotlib import pyplot as plt
import scipy
import csv


# see https://github.com/albermax/innvestigate/blob/master/examples/notebooks/imagenet_compare_methods.ipynb for a list of alternative methods
methods = [ # tuple with method,     params,                  label
#            ("deconvnet",            {},                      "Deconvnet"),
#            ("guided_backprop",      {},                      "Guided Backprop"),
#            ("deep_taylor.bounded",  {"low": -1, "high": 1},  "DeepTaylor"),
#            ("input_t_gradient",     {},                      "Input * Gradient"),
#            ("lrp.z",                {},                      "LRP-Z"),
#            ("lrp.epsilon",          {"epsilon": 1},          "LRP-epsilon"),
#            ("lrp.alpha_1_beta_0",   {"neuron_selection_mode":"index"},     "LRP-alpha1beta0"),
        ("lrp.sequential_preset_a", {"neuron_selection_mode": "index", "epsilon": 1e-10}, "LRP-CMPalpha1beta0"), # LRP CMP rule taken from https://github.com/berleon/when-explanations-lie/blob/master/when_explanations_lie.py
]

hipp_nifti = nib.load(data_overlay[0])  # assume it is already 32bit float format
new_data = np.zeros((121, 145, 121), dtype=np.float32) 

for k in [0]: #range(20):
    mymodel = load_model('model_checkpoints/resmodel_wb_whole_ds.hdf5') #load_model('model_checkpoints/resmodel_wb_cv%d.best.hdf5' % (k+1))
    #mymodel.summary()
    #model_wo_softmax = iutils.keras.graph.model_wo_softmax(mymodel)  ## sometimes raises: ValueError: The name "dense_1" is used 2 times in the model. All layer names should be unique.
    #model_wo_softmax = Model(inputs=mymodel.inputs,
    #                          outputs=iutils.keras.graph.pre_softmax_tensors(mymodel.outputs),
    #                          name=(mymodel.name + '_wo_softmax')) 
    #model_wo_softmax.summary()
    mymodel.layers[-1].activation=tf.keras.activations.linear
    mymodel.save('tmp_wo_softmax.hdf5')
    model_wo_softmax = load_model('tmp_wo_softmax.hdf5')
    if (k==0):
        model_wo_softmax.summary()

    # create analyzer
    analyzers = []
    for method in methods:
        #analyzer = innvestigate.create_analyzer("deep_taylor.bounded", model_wo_softmax, **params )
        analyzer = innvestigate.create_analyzer(method[0], model_wo_softmax, **method[1])
        # Some analyzers require training.
        #   analyzer.fit(test_img, batch_size=30, verbose=1)
        #  analyzers.append(analyzer)
     
    for indx in range(len(grps)):
        test_img = images[indx]
        #test_orig = images_orig[indx]
        #print('test image for subject of binary group: %d' % test_Y[subj_idx, 1]) # first col will indicate CN, second col indicates MCI/AD
        #print('test image for subject of ADNI diagnosis: %d [1-CN, 3-LMCI, 4-AD]' % testgrps.Group.to_numpy(dtype=np.int)[subj_idx])

        ####print('test subject ID %s' % grps.RID.to_numpy(dtype=np.int)[indx])

        test_img = np.reshape(test_img, (1,)+ test_img.shape) # add first subj index again to mimic original array structure
        #test_orig = np.reshape(test_orig, (1,)+ test_orig.shape) # add first subj index again to mimic original array structure

        #for method,analyzer in zip(methods, analyzers):
        a = np.reshape(analyzer.analyze(test_img, neuron_selection=1), test_img.shape[1:4])
        #np.clip(a, a_min=0, a_max=None, out=a)
        #a = scipy.ndimage.filters.gaussian_filter(a, sigma=0.8) # smooth activity image
        #scale = np.quantile(a, 0.99) # no need for abs(a)
        #if scale!=0:  # ignore if relevance maps contains only zeros, output will be zero as well
        #    a = (a/scale)

        a = np.flip(a) # flip all positions
        a = np.transpose(a, (1, 2, 0)) # reorder dimensions from coronal view z*x*y back to x*y*z

        print('saving lrp_maps_AIBL/lrp_map_grp%d_%04d_whole_ds_model.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx])) #print('saving lrp_map_grp%d_%s_cv%d.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx], (k+1)))
        new_data[x_range_from:x_range_to, y_range_from:y_range_to, z_range_from:z_range_to] = a
        nifti = nib.Nifti1Image(new_data, hipp_nifti.affine, hipp_nifti.header)
        nifti.to_filename('lrp_maps_AIBL/lrp_map_grp%d_%04d_whole_ds_model.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx])) #'lrp_map_grp%d_%s_cv%d.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx], (k+1)))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 100, 100, 120, 5)  140
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 50, 50, 60, 5)     0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 60, 5)     20
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 50, 50, 60, 5)     680
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 25, 25, 30, 5)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 30, 5)     20
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 25, 25, 30, 5)     680
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 12, 12, 15, 5)     0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 15, 5)     20
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10800)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10800)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                691264
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 694,970
# Trainable params: 694,940
# Non-trainable params: 30
# _________________________________________________________________
# saving lrp_maps_AIBL/lrp_map_grp1_1000_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1001_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1005_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_0100_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1013_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0101_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1020_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1024_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1025_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1027_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_0102_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1032_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1050_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1056_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0105_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1066_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1067_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1078_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_0107_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1089_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1090_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1091_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1094_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1095_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1098_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_0109_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1100_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1109_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_0111_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1122_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1125_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_0112_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0113_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1146_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1147_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1153_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1174_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0117_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1183_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1184_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1186_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1187_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0118_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1191_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1192_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1193_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1194_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1196_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1198_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1209_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1214_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1215_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1218_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0121_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1222_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1224_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1225_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1228_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1230_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1234_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1236_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1237_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1238_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0123_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1241_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1249_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1251_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1255_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1257_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1258_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0125_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1260_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1261_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1262_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1264_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1265_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1266_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_0126_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1272_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1273_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1277_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1278_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1279_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0127_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1281_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1283_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1285_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1286_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1287_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1290_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1291_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1293_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1295_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1298_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_0012_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1302_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1303_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1304_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1308_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1309_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1311_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1312_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1316_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1322_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1324_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1327_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1328_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1329_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1330_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1332_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1334_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1335_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1337_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1339_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1340_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1341_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1344_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1345_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1349_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0134_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1356_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0135_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1360_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1361_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1365_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1366_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1368_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1370_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1372_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1373_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1374_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1375_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1378_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1382_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1384_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1385_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1386_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0138_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1390_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1391_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1392_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1393_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1394_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1396_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1397_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1398_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1401_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1405_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1406_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1408_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1410_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1411_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1412_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1413_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1415_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1416_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1417_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1418_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1419_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1421_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1422_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1423_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1424_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1426_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1428_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1429_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0142_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1431_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1432_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1435_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1436_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1437_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1439_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1440_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1441_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1442_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1443_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1444_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1449_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0144_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1451_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1453_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1454_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1455_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1456_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1457_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1461_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1462_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1467_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1469_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0146_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1471_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0147_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1483_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1484_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1486_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0148_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1494_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1496_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1498_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1499_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0149_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0014_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1501_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1502_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1503_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1504_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1510_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1512_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1513_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1517_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1518_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1519_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1520_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1521_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_1522_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1526_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_0152_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp1_1531_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp3_1537_whole_ds_model.nii
# saving lrp_maps_AIBL/lrp_map_grp2_0153_whole_ds_model.nii
