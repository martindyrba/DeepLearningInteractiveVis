# %%
# Import data from Excel sheet
import pandas as pd
df = pd.read_excel('/data_dzne_archiv2/Studien/Deep_Learning_Visualization/data/hippocampus_volume_relevance_DELCODE.xlsx', sheet_name='DELCODE_LRP_CMP')
#print(df)
sid = df['SID']
grp = df['prmdiag']
age = df['age']
sex = df['sex_bin_1female']
tiv = df['TIV_CAT12']
field = df['FieldStrength']
amybin = df['ratio_Abeta42_40_pos']
grpbin = (grp > 0) # 0=CN, ...

# %%
# Scan for nifti file names
import glob
dataDELCODE_CN = sorted(glob.glob('/data_dzne_archiv2/Studien/Deep_Learning_Visualization/data/mwp1_CAT12_DELCODE/0_CN/*.nii.gz'))
dataDELCODE_MCI = sorted(glob.glob('/data_dzne_archiv2/Studien/Deep_Learning_Visualization/data/mwp1_CAT12_DELCODE/2_MCI/*.nii.gz'))
dataDELCODE_AD = sorted(glob.glob('/data_dzne_archiv2/Studien/Deep_Learning_Visualization/data/mwp1_CAT12_DELCODE/5_AD/*.nii.gz'))
dataFiles = dataDELCODE_CN + dataDELCODE_MCI + dataDELCODE_AD
numfiles = len(dataFiles)
print('Found ', str(numfiles), ' nifti files')
# Out:
# Found  474  nifti files

# %%
# Match covariate information
import re
import numpy as np
from keras.utils import to_categorical
debug = False
cov_idx = [-1] * numfiles # list; array: np.full((numfiles, 1), -1, dtype=int)
print('Matching covariates for loaded files ...')
for i,id in enumerate(sid):
  p = [j for j,x in enumerate(dataFiles) if re.search('_%s' % id, x)] # extract ID numbers from filename, translate to Excel row index
  if len(p)==0:
    if debug: print('Did not find %04d' % id) # did not find Excel sheet subject ID in loaded file selection
  else:
    if debug: print('Found %04d in %s: %s' % (id, p[0], dataFiles[p[0]]))
    cov_idx[p[0]] = i # store Excel index i for data file index p[0]
print('Checking for scans not found in Excel sheet: ', sum(x<0 for x in cov_idx))

labels = pd.DataFrame({'Group':grpbin}).iloc[cov_idx, :]
labels = to_categorical(np.asarray(labels)) # use grps to access original labels
grps = pd.DataFrame({'Group':grp, 'RID':sid}).iloc[cov_idx, :]
# Out:
# Using TensorFlow backend.
# Matching covariates for loaded files ...
# Checking for scans not found in Excel sheet:  0

# %%
# Load residualized data from disk
import h5py
hf = h5py.File('residuals_DELCODE_wb_mwp1_CAT12_MNI.hdf5', 'r')
hf.keys # read keys
images = np.array(hf.get('images'))
hf.close()
print(images.shape)
# Out:
# (474, 100, 100, 120, 1)

# %%
# specify version of tensorflow
#%tensorflow_version 1.x
#%tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
# disable tensorflow deprecation warnings
import logging
logging.getLogger('tensorflow').disabled=True
# downgrade to specific version
#!pip install tensorflow-gpu==1.15
#import tensorflow as tf
#print(tf.__version__)
#from keras.backend.tensorflow_backend import set_session
#config = tf.ConfigProto(
#    gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.8)
#    # device_count = {'GPU': 1}
#)
#config.gpu_options.allow_growth = False #True
#session = tf.Session(config=config)
#set_session(session)
# Out:
# 1.15.5

# %%
import nibabel as nib

# define FOV to reduce required memory size
x_range_from = 10; x_range_to = 110
y_range_from = 13; y_range_to = 133
z_range_from = 5; z_range_to = 105

data_overlay = sorted(glob.glob('Hippocampus_masks/aal_hippocampus.nii*'))

# %%
# Load CNN model from disk --> save predictions
from keras.models import load_model

batch_size = 20

for k in [0]: #range(20):
    mymodel = load_model('model_checkpoints/resmodel_wb_whole_ds.hdf5') #load_model('model_checkpoints/resmodel_wb_cv%d.best.hdf5' % (k+1))
    #mymodel.summary()
    pred = mymodel.predict(images, batch_size=batch_size)
    # only output prediction scores for AD output neuron
    results = pd.DataFrame({'SID':grps.RID, 'Group':grps.Group, 'pred':pred[:,1]})
    results.to_csv('results_wholeds_DELCODE_predictions.csv')
# Out:
# 2023-11-23 17:00:37.580325: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-11-23 17:00:37.587826: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3192500000 Hz
# 2023-11-23 17:00:37.588425: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xadff9b0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-11-23 17:00:37.588450: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-11-23 17:00:37.591222: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-11-23 17:00:37.690528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-23 17:00:37.690794: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xad93bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-23 17:00:37.690821: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 6000, Compute Capability 7.5
# 2023-11-23 17:00:37.691085: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-23 17:00:37.691215: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Quadro RTX 6000 major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:0b:00.0
# 2023-11-23 17:00:37.691506: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-11-23 17:00:37.693213: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-11-23 17:00:37.694730: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-11-23 17:00:37.695100: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-11-23 17:00:37.697044: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-11-23 17:00:37.698707: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2023-11-23 17:00:37.703835: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-11-23 17:00:37.704059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-23 17:00:37.704270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-23 17:00:37.704360: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2023-11-23 17:00:37.704491: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-11-23 17:00:37.704801: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-11-23 17:00:37.704823: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2023-11-23 17:00:37.704828: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2023-11-23 17:00:37.705004: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-23 17:00:37.705198: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-23 17:00:37.705370: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22531 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:0b:00.0, compute capability: 7.5)
# 2023-11-23 17:00:40.467820: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-11-23 17:00:40.745540: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-11-23 17:00:41.810411: W tensorflow/stream_executor/cuda/redzone_allocator.cc:312] Not found: ./bin/ptxas not found
# Relying on driver to perform ptx compilation. This message will be only logged once.

# %%
# Load CNN model from disk
from keras.models import load_model, Model
#!pip install innvestigate
import innvestigate
import innvestigate.utils as iutils
import numpy as np
from matplotlib import pyplot as plt
import scipy
import csv


# see https://github.com/albermax/innvestigate/blob/master/examples/notebooks/imagenet_compare_methods.ipynb for a list of alternative methods
methods = [ # tuple with method,     params,                  label
#            ("deconvnet",            {},                      "Deconvnet"),
#            ("guided_backprop",      {},                      "Guided Backprop"),
#            ("deep_taylor.bounded",  {"low": -1, "high": 1},  "DeepTaylor"),
#            ("input_t_gradient",     {},                      "Input * Gradient"),
#            ("lrp.z",                {},                      "LRP-Z"),
#            ("lrp.epsilon",          {"epsilon": 1},          "LRP-epsilon"),
#            ("lrp.alpha_1_beta_0",   {"neuron_selection_mode":"index"},     "LRP-alpha1beta0"),
        ("lrp.sequential_preset_a", {"neuron_selection_mode": "index", "epsilon": 1e-10}, "LRP-CMPalpha1beta0"), # LRP CMP rule taken from https://github.com/berleon/when-explanations-lie/blob/master/when_explanations_lie.py
]

hipp_nifti = nib.load(data_overlay[0])  # assume it is already 32bit float format
new_data = np.zeros((121, 145, 121), dtype=np.float32) 

for k in [0]: #range(20):
    mymodel = load_model('model_checkpoints/resmodel_wb_whole_ds.hdf5') #load_model('model_checkpoints/resmodel_wb_cv%d.best.hdf5' % (k+1))
    #mymodel.summary()
    #model_wo_softmax = iutils.keras.graph.model_wo_softmax(mymodel)  ## sometimes raises: ValueError: The name "dense_1" is used 2 times in the model. All layer names should be unique.
    #model_wo_softmax = Model(inputs=mymodel.inputs,
    #                          outputs=iutils.keras.graph.pre_softmax_tensors(mymodel.outputs),
    #                          name=(mymodel.name + '_wo_softmax')) 
    #model_wo_softmax.summary()
    mymodel.layers[-1].activation=tf.keras.activations.linear
    mymodel.save('tmp_wo_softmax.hdf5')
    model_wo_softmax = load_model('tmp_wo_softmax.hdf5')
    if (k==0):
        model_wo_softmax.summary()

    # create analyzer
    analyzers = []
    for method in methods:
        #analyzer = innvestigate.create_analyzer("deep_taylor.bounded", model_wo_softmax, **params )
        analyzer = innvestigate.create_analyzer(method[0], model_wo_softmax, **method[1])
        # Some analyzers require training.
        #   analyzer.fit(test_img, batch_size=30, verbose=1)
        #  analyzers.append(analyzer)
     
    for indx in range(len(grps)):
        test_img = images[indx]
        #test_orig = images_orig[indx]
        #print('test image for subject of binary group: %d' % test_Y[subj_idx, 1]) # first col will indicate CN, second col indicates MCI/AD
        #print('test image for subject of ADNI diagnosis: %d [1-CN, 3-LMCI, 4-AD]' % testgrps.Group.to_numpy(dtype=np.int)[subj_idx])

        ####print('test subject ID %s' % grps.RID.to_numpy(dtype=np.int)[indx])

        test_img = np.reshape(test_img, (1,)+ test_img.shape) # add first subj index again to mimic original array structure
        #test_orig = np.reshape(test_orig, (1,)+ test_orig.shape) # add first subj index again to mimic original array structure

        #for method,analyzer in zip(methods, analyzers):
        a = np.reshape(analyzer.analyze(test_img, neuron_selection=1), test_img.shape[1:4])
        #np.clip(a, a_min=0, a_max=None, out=a)
        #a = scipy.ndimage.filters.gaussian_filter(a, sigma=0.8) # smooth activity image
        #scale = np.quantile(a, 0.99) # no need for abs(a)
        #if scale!=0:  # ignore if relevance maps contains only zeros, output will be zero as well
        #    a = (a/scale)

        a = np.flip(a) # flip all positions
        a = np.transpose(a, (1, 2, 0)) # reorder dimensions from coronal view z*x*y back to x*y*z

        print('saving lrp_maps_DELCODE/lrp_map_grp%d_%s_whole_ds_model.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx])) #print('saving lrp_map_grp%d_%s_cv%d.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx], (k+1)))
        new_data[x_range_from:x_range_to, y_range_from:y_range_to, z_range_from:z_range_to] = a
        nifti = nib.Nifti1Image(new_data, hipp_nifti.affine, hipp_nifti.header)
        nifti.to_filename('lrp_maps_DELCODE/lrp_map_grp%d_%s_whole_ds_model.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx])) #'lrp_map_grp%d_%s_cv%d.nii' % (grps.Group.iloc[indx], grps.RID.iloc[indx], (k+1)))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 100, 100, 120, 5)  140
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 50, 50, 60, 5)     0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 60, 5)     20
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 50, 50, 60, 5)     680
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 25, 25, 30, 5)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 30, 5)     20
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 25, 25, 30, 5)     680
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 12, 12, 15, 5)     0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 15, 5)     20
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10800)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10800)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                691264
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 694,970
# Trainable params: 694,940
# Non-trainable params: 30
# _________________________________________________________________
# saving lrp_maps_DELCODE/lrp_map_grp0_011d501d1_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_037182b37_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_0449f2db9_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_0901942a8_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_0ffe6f31c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_1074f23ec_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_11a6e3c08_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_14affcc98_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_157dec7d5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_172ff8939_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_18f824f6b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_1c4220ec7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_1e0481d24_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_1ef92e9c3_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_1feef8372_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_213b91d25_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_2275a05f4_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_22877da0b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_249a8028e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_2bb4ae405_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_2c172a2a4_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_2c4269234_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_2ef37a297_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_2efdda48b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_31cc7f41f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_32d5a39e1_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_3300076e2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_3737eef10_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_3b6a99646_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_3b86bf40b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_3bcf0d9d2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_3f194bc00_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_3f27b85a6_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_40a5f2347_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_41fd5f400_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_4267264d6_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_4ba64d860_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_4db84ad1e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_4e2db8e02_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_4f697f4e5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_4f7d19863_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_5127c5f26_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_51baa72fc_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_52ebd5c97_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_56821e84f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_569a8f2f2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_57df8d6f2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_59d4532d4_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_5ca2bd986_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_5f61c6dd3_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_5fa28de60_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_6257a8a41_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_635c9eef5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_6b03a7325_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_6c711c6f5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_6e661b712_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_704002c6e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_72984fc3b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_739bcc050_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_781929efb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_791f24593_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_7b4a90458_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_7c61f08f9_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_7d127cf2a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_7e5b6506c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_82bc79aa4_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_8412144d4_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_8522b0508_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_86bc6cb0e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_8a025f647_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_8eb568ce1_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_94fa0a409_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_953d43cef_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_97d13cd70_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_9823c6153_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_99d318d74_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_9cf65bd61_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_9d9c4884f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_9ff13e297_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_a092a7bfa_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_a7618c667_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_abb6b2538_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_abe29e2a5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b13d32c0a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b35253a7a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b393e08ba_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b40c1e4be_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b46cebb5e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b4cb00ecf_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b52b1fc2d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b83e16246_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b89a3c399_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b8cd0834e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_bd583bc99_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_c3611c3bb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_c5c674064_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_c63ade830_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_c9f9dee06_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_ca4672480_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_cbc6b9fb6_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_d10c9127a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_d284daff9_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_d366bf38a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_d5240fa6e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_d5ecfe64c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_d6df7553a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_db5773624_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_de49ee502_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_df196c649_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_dfb6d1901_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_dff40316e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_e1960dc89_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_e1e4ff481_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_e248866cb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_e3cf25b67_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_ec43af629_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_f6b6a2f7f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_f71815317_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_f899b6390_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_fc270810d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_fdabdb866_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_ff6b0f91f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_01c968c29_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_02939fa93_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_0633efccb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_0675b30cb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_11ee94b0e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_13c6322ae_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_144014f58_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_1488f85ad_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_18209aead_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_20a9d6518_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_254af09a2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_25ea9e7f7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_2cdb3a53b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_2d410a65f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_3007200ab_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_3686a41ec_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_37c00d740_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_3c4b2656e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_3fd91223d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_437b2791f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_440b5327f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_460b576e2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_4798dd03c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_4a1bb1546_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_52dfe2c29_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_5339c1ff7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_57e9fafc7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_58aedadbc_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_59d4008a7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_5a9a5f91b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_5e0f5d910_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_5fabfb164_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_647b6a5ed_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_66d373fff_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_69c3dacfb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_6d6dd7aea_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_6e15fe9ec_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_72c7bba10_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_73e17d7e2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_74dd3f52d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_750a1c915_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_7957f58ee_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_7e74ee245_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_80146d3be_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_8240d1812_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_86f85e91d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_881977bc8_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_88571e8a9_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_8e1bd328f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_8f33743ba_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_91c63ee73_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_931132250_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_93f563391_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_96357826f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_964ab82c5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_9c8c5c08c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_9d346b71b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_9f2c00965_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_a5fcb8232_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_a69aad6bb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_a8937ab2e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_a91e41ab5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_ab6acf9a3_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_ae18bd30f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_afa0f0bb2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b05b68024_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b14b07c01_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b2945a9bb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b31733a0c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b6103a465_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_b9b0afb9d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_c4f20ef75_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_c905714c7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_c9d453efd_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_ca8cd6a27_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_d1cea034b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_d310d786d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_d7af7c39b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_d880c4f4d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_d8c52ae45_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_da14eb118_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_db2b6d3e1_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_dd893aeed_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_e1c4b0748_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_e37b09076_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_e716a1714_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_ee19c801d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_efb75102b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_f32da4c94_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_f670135db_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_f8db638f8_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_fda439fe0_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp0_ff28c9d34_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_12be4c67c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_13488115b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_147dcf43b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_1eebab647_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_23cd008c9_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_2d73e8996_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_2d82dd5e3_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_3c195bec6_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_41a2ff167_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_475b9bfe2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_483dc63c6_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_4bd7938d5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_4c8677a7f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_4e73cdc52_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_536ad028e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_65c8dfd34_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_682305c91_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_700039701_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_74284cbf3_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_779893593_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_77e426495_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_7bc92ad6d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_7c651b5d1_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_822a3a811_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_834fb0636_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_836c233ff_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_868782d46_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_86b7754e0_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_871ae55c9_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_89a40fc7e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_8eef0619f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_91383c1f8_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_95c562d3e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_9cf012413_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_9f6dd35d4_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_a936b9c79_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_aaa7ce134_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_b093bca1e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_b67b41df4_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_b7b9f01f5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_bc177df98_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_c35ddeb62_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_c81213449_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_ca971f829_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_cb0806279_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_d0887896f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_d4055734e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_d468bea63_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_df57b92f6_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_e25c67e62_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_e2cf30aa0_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_e6b521171_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_f99275577_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_fa30fdef7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_fbebee616_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_03a0a6663_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_04b06dc4d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_04cbb28bb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_05595022c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_0588be6c5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_0a8d02f2b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_0f1b4b7ac_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_1169cb29f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_12510d07d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_14532a273_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_16cf80a1a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_191e8e85d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_1b349d5ca_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_1d48057fd_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_1ece6ef85_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_1f2ce5457_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_278d3e09d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_29b4339b6_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_2bf7ca999_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_2d0c30f83_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_2e2857631_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_304283db7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_312c25423_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_383d33cde_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_3e330542a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_404309f27_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_40ea07c4b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_428978e36_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_4365df385_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_46c3433d4_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_4850fb0c1_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_4bfeecc3c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_504f71ebe_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_53199d407_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_545f96b8d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_54e0f059e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_5598d51dd_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_5c4e89915_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_63258afb4_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_6395ff56c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_6580eaf4b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_660f27d45_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_6c679cd78_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_6d517ce97_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_6ecf96ab0_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_6fb1f7b34_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_702458ca4_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_74816bbba_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_74a556abd_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_74d781eee_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_75d14b5ca_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_75d45f9f7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_76b663601_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_7808e89c0_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_7898c9f2d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_7bd198732_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_7c86c18fc_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_81489f2bb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_83e434fc7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_849bda713_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_8740df278_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_882f895e7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_88d028fe3_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_9766e9c38_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_9b16d9da3_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_9f4e60065_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_a5cceacea_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_a95bca61d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_ad73d5585_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_adf756d40_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_ae818e1d7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_b003f2c8c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_b18d729af_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_b38c31704_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_b56914910_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_b750d9dbe_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_bb1c45a71_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_bc86f0ab2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_bcae977b3_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_bd6b65027_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_c31b2cac2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_c3b025cae_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_cd3bf904f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_d621c4094_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_d6334c64c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_dd0c715af_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_e42f4862b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_e7967bcd4_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_e8d68a81a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_ef3fe3af2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_ef4adf523_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_f1ab9da05_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_f2a767eaa_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_f328caa31_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_f4b259d58_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_f4ba91dc6_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_fa491029f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_fc3c650cd_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_fd225d1ef_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp2_fdb1d843b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_01643c48b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_1b6c308bb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_1e36df350_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_279c804fc_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_360af04f9_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_37e2a9a8d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_3a008313c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_3fef4f592_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_40c6470f2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_440490ab9_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_575de8e29_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_5cbfe44a2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_66a856983_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_7c58de16b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_800ad3944_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_8de59cd14_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_90ae05823_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_999c0bcdf_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_9bada91fb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_a064ce010_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_abea7cf25_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_ad0d19af0_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_c54be1cb9_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_c6c639f6e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_d350c3a5a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_d45929e58_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_d99e1a32e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_e08d2a745_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_e8a9dd58e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_ec6ef4467_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_f98419539_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_01490270a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_01dc83c85_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_040356085_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_0544f6a46_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_069c5d6ca_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_0709f43de_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_095b06fe7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_1230b7af2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_12c736dd8_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_16437ed4f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_1d01cdaf5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_220e18c57_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_2c30e6116_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_2dd25390a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_34f06b217_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_3628fc36f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_46b9c72ad_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_48387a07e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_491a6bfc9_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_4bb9f9da0_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_4d48dfe14_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_58f3f8bfb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_5a22d09c3_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_5bc91aa49_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_60a8dd7f5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_632000a93_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_64f3f4c05_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_6813512ec_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_6829e1ce3_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_6b1f0ca5e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_6ca5bbf71_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_6dc95ea8c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_6e529ac92_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_72e485c23_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_74def0e0c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_766b96f80_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_7a14bdf5d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_85eb9b1a2_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_8e66edf5e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_90af3fc23_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_9126540a5_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_939754b04_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_9446d0c1d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_94903d78c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_986df416f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_999bf662e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_9a8443730_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_9c9981e04_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_9dc5af14f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_9ebb7d181_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_a06b9eaa0_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_a85193ba7_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_b257195fb_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_b77589356_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_b9ab9ccac_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_bb1441134_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_bbb5dedd3_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_bc789238a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_c88ff511b_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_cf910b6f9_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_d23ebb73d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_d28fc147c_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_def838ca1_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_df58381f8_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_e20afe43f_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_e71c3bc9d_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_eb95738e8_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_f7c36103e_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_f816d269a_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_f8d601860_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_fade343c8_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_fbc8a48a0_whole_ds_model.nii
# saving lrp_maps_DELCODE/lrp_map_grp5_ff5a29440_whole_ds_model.nii
