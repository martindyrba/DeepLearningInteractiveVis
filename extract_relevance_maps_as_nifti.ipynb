# %%
# Import data from Excel sheet
import pandas as pd
df = pd.read_excel('ADNI combined.xlsx', sheet_name='sample')
#print(df)
sid = df['RID']
grp = df['Group at scan date (1=CN, 2=EMCI, 3=LMCI, 4=AD, 5=SMC)']
age = df['Age at scan']
sex = df['Sex (1=female)']
tiv = df['TIV']
field = df['MRI_Field_Strength']
grpbin = (grp > 1) # 1=CN, ...

# %%
# Scan for nifti file names
import glob
dataAD = sorted(glob.glob('mwp1_MNI/AD/*.nii.gz'))
dataLMCI = sorted(glob.glob('mwp1_MNI/LMCI/*.nii.gz'))
dataCN = sorted(glob.glob('mwp1_MNI/CN/*.nii.gz'))
dataFiles = dataAD + dataLMCI + dataCN
numfiles = len(dataFiles)
print('Found ', str(numfiles), ' nifti files')
# Out:
# Found  663  nifti files

# %%
import re
debug = False
cov_idx = [-1] * numfiles # list; array: np.full((numfiles, 1), -1, dtype=int)
print('Matching covariates for loaded files ...')
for i,id in enumerate(sid):
    p = [j for j,x in enumerate(dataFiles) if re.search('_%04d_' % id, x)] # translate ID numbers to four-digit numbers, get both index and filename
    if len(p)==0:
        if debug: print('Did not find %04d' % id) # did not find Excel sheet subject ID in loaded file selection
    else:
        if debug: print('Found %04d in %s: %s' % (id, p[0], dataFiles[p[0]]))
        cov_idx[p[0]] = i # store Excel index i for data file index p[0]
print('Checking for scans not found in Excel sheet: ', sum(x<0 for x in cov_idx))

labels = pd.DataFrame({'Group':grpbin}).iloc[cov_idx, :]
grps = pd.DataFrame({'Group':grp, 'RID':sid}).iloc[cov_idx, :]
# Out:
# Matching covariates for loaded files ...
# Checking for scans not found in Excel sheet:  0

# %%
#Load residualized data from disk
import h5py
import numpy as np
hf = h5py.File('residuals_wb_mwp1_MNI.hdf5', 'r')
hf.keys # read keys
labels = np.array(hf.get('labels')) # note: was of data frame type before
images = np.array(hf.get('images'))
hf.close()

# %%
import tensorflow as tf
print(tf.__version__)
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto(
    gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=1)
    # device_count = {'GPU': 1}
)
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
set_session(session)
# Out:
# 1.15.0
# Using TensorFlow backend.

# %%
import nibabel as nib

# define FOV to reduce required memory size
x_range_from = 10; x_range_to = 110
y_range_from = 10; y_range_to = 130
z_range_from = 5; z_range_to = 105

data_overlay = sorted(glob.glob('Hippocampus_masks/Hipp*_HarvOx_GMmasked0.5_MNI.nii*'))

# %%
# Load CNN model from disk
from keras.models import load_model, Model
#!pip install innvestigate
import innvestigate
import innvestigate.utils as iutils
import numpy as np
from matplotlib import pyplot as plt
import scipy
import csv


# see https://github.com/albermax/innvestigate/blob/master/examples/notebooks/imagenet_compare_methods.ipynb for a list of alternative methods
methods = [ # tuple with method,     params,                  label
#            ("deconvnet",            {},                      "Deconvnet"),
#            ("guided_backprop",      {},                      "Guided Backprop"),
#            ("deep_taylor.bounded",  {"low": -1, "high": 1},  "DeepTaylor"),
#            ("input_t_gradient",     {},                      "Input * Gradient"),
#            ("lrp.z",                {},                      "LRP-Z"),
#            ("lrp.epsilon",          {"epsilon": 1},          "LRP-epsilon"),
            ("lrp.alpha_1_beta_0",   {"neuron_selection_mode":"index"},     "LRP-alpha1beta0"),
]

hipp_nifti = nib.load(data_overlay[0])  # assume it is already 32bit float format
new_data = np.zeros((121, 145, 121), dtype=np.float32) 

for k in [ 7 ]: #range(20):
    mymodel = load_model('newmodel/newmodel_wb_cv%d.hdf5' % (k+1))
    mymodel.name = 'newmodel_wb_cv%d.hdf5' % (k+1)
    #mymodel.summary()
    model_wo_softmax = iutils.keras.graph.model_wo_softmax(mymodel)  ## sometimes raises: ValueError: The name "dense_1" is used 2 times in the model. All layer names should be unique.
    #model_wo_softmax = Model(inputs=mymodel.inputs,
    #                          outputs=iutils.keras.graph.pre_softmax_tensors(mymodel.outputs),
    #                          name=(mymodel.name + '_wo_softmax')) 
    #model_wo_softmax.summary()

    # create analyzer
    analyzers = []
    for method in methods:
        #analyzer = innvestigate.create_analyzer("deep_taylor.bounded", model_wo_softmax, **params )
        analyzer = innvestigate.create_analyzer(method[0], model_wo_softmax, **method[1])
        # Some analyzers require training.
        #   analyzer.fit(test_img, batch_size=30, verbose=1)
        #  analyzers.append(analyzer)
     
    for indx in range(len(grps)):
        test_img = images[indx]
        #test_orig = images_orig[indx]
        #print('test image for subject of binary group: %d' % test_Y[subj_idx, 1]) # first col will indicate CN, second col indicates MCI/AD
        #print('test image for subject of ADNI diagnosis: %d [1-CN, 3-LMCI, 4-AD]' % testgrps.Group.to_numpy(dtype=np.int)[subj_idx])

        ####print('test subject ID %s' % grps.RID.to_numpy(dtype=np.int)[indx])

        test_img = np.reshape(test_img, (1,)+ test_img.shape) # add first subj index again to mimic original array structure
        #test_orig = np.reshape(test_orig, (1,)+ test_orig.shape) # add first subj index again to mimic original array structure

        #for method,analyzer in zip(methods, analyzers):
        a = np.reshape(analyzer.analyze(test_img, neuron_selection=1), test_img.shape[1:4])
        np.clip(a, a_min=0, a_max=None, out=a)
        a = scipy.ndimage.filters.gaussian_filter(a, sigma=0.8) # smooth activity image
        scale = np.quantile(a, 0.99) # no need for abs(a)
        if scale!=0:  # ignore if relevance maps contains only zeros, output will be zero as well
            a = (a/scale)

        a = np.flip(a) # flip all positions
        a = np.transpose(a, (1, 2, 0)) # reorder dimensions from coronal view z*x*y back to x*y*z

        new_data[x_range_from:x_range_to, y_range_from:y_range_to, z_range_from:z_range_to] = a
        nifti = nib.Nifti1Image(new_data, hipp_nifti.affine, hipp_nifti.header)
        print('saving lrp_map_%04d_cv%d.nii' % (grps.RID.iloc[indx], (k+1)))
        nifti.to_filename('lrp_map_%04d_cv%d.nii' % (grps.RID.iloc[indx], (k+1)))
# Out:
# saving lrp_map_0729_cv8.nii
# saving lrp_map_1057_cv8.nii
# saving lrp_map_5165_cv8.nii
# saving lrp_map_5187_cv8.nii
# saving lrp_map_0572_cv8.nii
# saving lrp_map_5038_cv8.nii
# saving lrp_map_5119_cv8.nii
# saving lrp_map_1130_cv8.nii
# saving lrp_map_0101_cv8.nii
# saving lrp_map_5196_cv8.nii
# saving lrp_map_1030_cv8.nii
# saving lrp_map_5027_cv8.nii
# saving lrp_map_5037_cv8.nii
# saving lrp_map_5224_cv8.nii
# saving lrp_map_5252_cv8.nii
# saving lrp_map_6303_cv8.nii
# saving lrp_map_5071_cv8.nii
# saving lrp_map_0658_cv8.nii
# saving lrp_map_0702_cv8.nii
# saving lrp_map_1117_cv8.nii
# saving lrp_map_1326_cv8.nii
# saving lrp_map_5032_cv8.nii
# saving lrp_map_5057_cv8.nii
# saving lrp_map_5251_cv8.nii
# saving lrp_map_5240_cv8.nii
# saving lrp_map_4924_cv8.nii
# saving lrp_map_0042_cv8.nii
# saving lrp_map_0331_cv8.nii
# saving lrp_map_0376_cv8.nii
# saving lrp_map_0887_cv8.nii
# saving lrp_map_5120_cv8.nii
# saving lrp_map_5241_cv8.nii
# saving lrp_map_5054_cv8.nii
# saving lrp_map_0408_cv8.nii
# saving lrp_map_0835_cv8.nii
# saving lrp_map_4964_cv8.nii
# saving lrp_map_0830_cv8.nii
# saving lrp_map_0214_cv8.nii
# saving lrp_map_0906_cv8.nii
# saving lrp_map_5013_cv8.nii
# saving lrp_map_5017_cv8.nii
# saving lrp_map_5087_cv8.nii
# saving lrp_map_0292_cv8.nii
# saving lrp_map_0997_cv8.nii
# saving lrp_map_5063_cv8.nii
# saving lrp_map_5112_cv8.nii
# saving lrp_map_5210_cv8.nii
# saving lrp_map_0552_cv8.nii
# saving lrp_map_5162_cv8.nii
# saving lrp_map_1010_cv8.nii
# saving lrp_map_1425_cv8.nii
# saving lrp_map_4980_cv8.nii
# saving lrp_map_5005_cv8.nii
# saving lrp_map_1346_cv8.nii
# saving lrp_map_4959_cv8.nii
# saving lrp_map_5062_cv8.nii
# saving lrp_map_5070_cv8.nii
# saving lrp_map_5208_cv8.nii
# saving lrp_map_1007_cv8.nii
# saving lrp_map_5205_cv8.nii
# saving lrp_map_4859_cv8.nii
# saving lrp_map_4968_cv8.nii
# saving lrp_map_5146_cv8.nii
# saving lrp_map_5016_cv8.nii
# saving lrp_map_5090_cv8.nii
# saving lrp_map_5029_cv8.nii
# saving lrp_map_5184_cv8.nii
# saving lrp_map_0160_cv8.nii
# saving lrp_map_0269_cv8.nii
# saving lrp_map_0667_cv8.nii
# saving lrp_map_0051_cv8.nii
# saving lrp_map_4994_cv8.nii
# saving lrp_map_5106_cv8.nii
# saving lrp_map_0166_cv8.nii
# saving lrp_map_0378_cv8.nii
# saving lrp_map_6039_cv8.nii
# saving lrp_map_0361_cv8.nii
# saving lrp_map_1427_cv8.nii
# saving lrp_map_4992_cv8.nii
# saving lrp_map_5028_cv8.nii
# saving lrp_map_5056_cv8.nii
# saving lrp_map_5058_cv8.nii
# saving lrp_map_5067_cv8.nii
# saving lrp_map_5095_cv8.nii
# saving lrp_map_0135_cv8.nii
# saving lrp_map_0227_cv8.nii
# saving lrp_map_0230_cv8.nii
# saving lrp_map_1043_cv8.nii
# saving lrp_map_5123_cv8.nii
# saving lrp_map_4971_cv8.nii
# saving lrp_map_4990_cv8.nii
# saving lrp_map_4997_cv8.nii
# saving lrp_map_5006_cv8.nii
# saving lrp_map_5059_cv8.nii
# saving lrp_map_5231_cv8.nii
# saving lrp_map_5138_cv8.nii
# saving lrp_map_5015_cv8.nii
# saving lrp_map_5275_cv8.nii
# saving lrp_map_0873_cv8.nii
# saving lrp_map_0973_cv8.nii
# saving lrp_map_0994_cv8.nii
# saving lrp_map_1004_cv8.nii
# saving lrp_map_1255_cv8.nii
# saving lrp_map_6142_cv8.nii
# saving lrp_map_4001_cv8.nii
# saving lrp_map_4009_cv8.nii
# saving lrp_map_4024_cv8.nii
# saving lrp_map_4039_cv8.nii
# saving lrp_map_4089_cv8.nii
# saving lrp_map_4136_cv8.nii
# saving lrp_map_4152_cv8.nii
# saving lrp_map_4153_cv8.nii
# saving lrp_map_4172_cv8.nii
# saving lrp_map_4192_cv8.nii
# saving lrp_map_4195_cv8.nii
# saving lrp_map_4201_cv8.nii
# saving lrp_map_4209_cv8.nii
# saving lrp_map_4211_cv8.nii
# saving lrp_map_4215_cv8.nii
# saving lrp_map_4223_cv8.nii
# saving lrp_map_4252_cv8.nii
# saving lrp_map_4258_cv8.nii
# saving lrp_map_4280_cv8.nii
# saving lrp_map_4282_cv8.nii
# saving lrp_map_4307_cv8.nii
# saving lrp_map_4338_cv8.nii
# saving lrp_map_4353_cv8.nii
# saving lrp_map_4373_cv8.nii
# saving lrp_map_4379_cv8.nii
# saving lrp_map_4477_cv8.nii
# saving lrp_map_4494_cv8.nii
# saving lrp_map_4500_cv8.nii
# saving lrp_map_4501_cv8.nii
# saving lrp_map_4526_cv8.nii
# saving lrp_map_4546_cv8.nii
# saving lrp_map_4549_cv8.nii
# saving lrp_map_4568_cv8.nii
# saving lrp_map_4583_cv8.nii
# saving lrp_map_4589_cv8.nii
# saving lrp_map_4591_cv8.nii
# saving lrp_map_4615_cv8.nii
# saving lrp_map_4625_cv8.nii
# saving lrp_map_4641_cv8.nii
# saving lrp_map_4657_cv8.nii
# saving lrp_map_4660_cv8.nii
# saving lrp_map_4672_cv8.nii
# saving lrp_map_4676_cv8.nii
# saving lrp_map_4686_cv8.nii
# saving lrp_map_4692_cv8.nii
# saving lrp_map_4696_cv8.nii
# saving lrp_map_4707_cv8.nii
# saving lrp_map_4718_cv8.nii
# saving lrp_map_4719_cv8.nii
# saving lrp_map_4728_cv8.nii
# saving lrp_map_4730_cv8.nii
# saving lrp_map_4732_cv8.nii
# saving lrp_map_4737_cv8.nii
# saving lrp_map_4755_cv8.nii
# saving lrp_map_4756_cv8.nii
# saving lrp_map_4770_cv8.nii
# saving lrp_map_4772_cv8.nii
# saving lrp_map_4774_cv8.nii
# saving lrp_map_4783_cv8.nii
# saving lrp_map_4792_cv8.nii
# saving lrp_map_4801_cv8.nii
# saving lrp_map_4802_cv8.nii
# saving lrp_map_4820_cv8.nii
# saving lrp_map_4827_cv8.nii
# saving lrp_map_4845_cv8.nii
# saving lrp_map_4853_cv8.nii
# saving lrp_map_4863_cv8.nii
# saving lrp_map_4867_cv8.nii
# saving lrp_map_4879_cv8.nii
# saving lrp_map_4887_cv8.nii
# saving lrp_map_4894_cv8.nii
# saving lrp_map_4905_cv8.nii
# saving lrp_map_4906_cv8.nii
# saving lrp_map_4910_cv8.nii
# saving lrp_map_4911_cv8.nii
# saving lrp_map_4912_cv8.nii
# saving lrp_map_4940_cv8.nii
# saving lrp_map_4949_cv8.nii
# saving lrp_map_4954_cv8.nii
# saving lrp_map_4962_cv8.nii
# saving lrp_map_4982_cv8.nii
# saving lrp_map_4984_cv8.nii
# saving lrp_map_5012_cv8.nii
# saving lrp_map_5018_cv8.nii
# saving lrp_map_5019_cv8.nii
# saving lrp_map_1155_cv8.nii
# saving lrp_map_4229_cv8.nii
# saving lrp_map_4251_cv8.nii
# saving lrp_map_0908_cv8.nii
# saving lrp_map_1074_cv8.nii
# saving lrp_map_1122_cv8.nii
# saving lrp_map_6258_cv8.nii
# saving lrp_map_0546_cv8.nii
# saving lrp_map_6427_cv8.nii
# saving lrp_map_0698_cv8.nii
# saving lrp_map_4543_cv8.nii
# saving lrp_map_0420_cv8.nii
# saving lrp_map_6073_cv8.nii
# saving lrp_map_4985_cv8.nii
# saving lrp_map_0142_cv8.nii
# saving lrp_map_4922_cv8.nii
# saving lrp_map_1046_cv8.nii
# saving lrp_map_4115_cv8.nii
# saving lrp_map_6334_cv8.nii
# saving lrp_map_6356_cv8.nii
# saving lrp_map_1063_cv8.nii
# saving lrp_map_0307_cv8.nii
# saving lrp_map_0644_cv8.nii
# saving lrp_map_1045_cv8.nii
# saving lrp_map_4729_cv8.nii
# saving lrp_map_4804_cv8.nii
# saving lrp_map_1218_cv8.nii
# saving lrp_map_1318_cv8.nii
# saving lrp_map_0867_cv8.nii
# saving lrp_map_4194_cv8.nii
# saving lrp_map_4203_cv8.nii
# saving lrp_map_1169_cv8.nii
# saving lrp_map_4714_cv8.nii
# saving lrp_map_4899_cv8.nii
# saving lrp_map_0150_cv8.nii
# saving lrp_map_0454_cv8.nii
# saving lrp_map_4302_cv8.nii
# saving lrp_map_0679_cv8.nii
# saving lrp_map_1418_cv8.nii
# saving lrp_map_1072_cv8.nii
# saving lrp_map_0671_cv8.nii
# saving lrp_map_0989_cv8.nii
# saving lrp_map_4945_cv8.nii
# saving lrp_map_0919_cv8.nii
# saving lrp_map_1269_cv8.nii
# saving lrp_map_0872_cv8.nii
# saving lrp_map_1380_cv8.nii
# saving lrp_map_0746_cv8.nii
# saving lrp_map_4300_cv8.nii
# saving lrp_map_4311_cv8.nii
# saving lrp_map_4630_cv8.nii
# saving lrp_map_0291_cv8.nii
# saving lrp_map_0296_cv8.nii
# saving lrp_map_1226_cv8.nii
# saving lrp_map_1106_cv8.nii
# saving lrp_map_1118_cv8.nii
# saving lrp_map_5047_cv8.nii
# saving lrp_map_4167_cv8.nii
# saving lrp_map_1300_cv8.nii
# saving lrp_map_0709_cv8.nii
# saving lrp_map_1187_cv8.nii
# saving lrp_map_0925_cv8.nii
# saving lrp_map_1419_cv8.nii
# saving lrp_map_4928_cv8.nii
# saving lrp_map_0200_cv8.nii
# saving lrp_map_1408_cv8.nii
# saving lrp_map_0778_cv8.nii
# saving lrp_map_1246_cv8.nii
# saving lrp_map_0285_cv8.nii
# saving lrp_map_0505_cv8.nii
# saving lrp_map_4250_cv8.nii
# saving lrp_map_4542_cv8.nii
# saving lrp_map_0123_cv8.nii
# saving lrp_map_0107_cv8.nii
# saving lrp_map_4189_cv8.nii
# saving lrp_map_0800_cv8.nii
# saving lrp_map_1414_cv8.nii
# saving lrp_map_0717_cv8.nii
# saving lrp_map_1052_cv8.nii
# saving lrp_map_1378_cv8.nii
# saving lrp_map_6274_cv8.nii
# saving lrp_map_6336_cv8.nii
# saving lrp_map_6180_cv8.nii
# saving lrp_map_6056_cv8.nii
# saving lrp_map_6297_cv8.nii
# saving lrp_map_4187_cv8.nii
# saving lrp_map_1186_cv8.nii
# saving lrp_map_1268_cv8.nii
# saving lrp_map_4015_cv8.nii
# saving lrp_map_4029_cv8.nii
# saving lrp_map_4030_cv8.nii
# saving lrp_map_4034_cv8.nii
# saving lrp_map_4035_cv8.nii
# saving lrp_map_4042_cv8.nii
# saving lrp_map_4053_cv8.nii
# saving lrp_map_4057_cv8.nii
# saving lrp_map_4058_cv8.nii
# saving lrp_map_4061_cv8.nii
# saving lrp_map_4077_cv8.nii
# saving lrp_map_4079_cv8.nii
# saving lrp_map_4094_cv8.nii
# saving lrp_map_4096_cv8.nii
# saving lrp_map_4114_cv8.nii
# saving lrp_map_4122_cv8.nii
# saving lrp_map_4131_cv8.nii
# saving lrp_map_4138_cv8.nii
# saving lrp_map_4162_cv8.nii
# saving lrp_map_4169_cv8.nii
# saving lrp_map_4170_cv8.nii
# saving lrp_map_4171_cv8.nii
# saving lrp_map_4197_cv8.nii
# saving lrp_map_4210_cv8.nii
# saving lrp_map_4214_cv8.nii
# saving lrp_map_4219_cv8.nii
# saving lrp_map_4240_cv8.nii
# saving lrp_map_4243_cv8.nii
# saving lrp_map_4244_cv8.nii
# saving lrp_map_4263_cv8.nii
# saving lrp_map_4287_cv8.nii
# saving lrp_map_4293_cv8.nii
# saving lrp_map_4294_cv8.nii
# saving lrp_map_4303_cv8.nii
# saving lrp_map_4324_cv8.nii
# saving lrp_map_4346_cv8.nii
# saving lrp_map_4354_cv8.nii
# saving lrp_map_4359_cv8.nii
# saving lrp_map_4363_cv8.nii
# saving lrp_map_4366_cv8.nii
# saving lrp_map_4377_cv8.nii
# saving lrp_map_4381_cv8.nii
# saving lrp_map_4394_cv8.nii
# saving lrp_map_4395_cv8.nii
# saving lrp_map_4402_cv8.nii
# saving lrp_map_4403_cv8.nii
# saving lrp_map_4406_cv8.nii
# saving lrp_map_4408_cv8.nii
# saving lrp_map_4414_cv8.nii
# saving lrp_map_4426_cv8.nii
# saving lrp_map_4430_cv8.nii
# saving lrp_map_4444_cv8.nii
# saving lrp_map_4456_cv8.nii
# saving lrp_map_4458_cv8.nii
# saving lrp_map_4462_cv8.nii
# saving lrp_map_4489_cv8.nii
# saving lrp_map_4502_cv8.nii
# saving lrp_map_4507_cv8.nii
# saving lrp_map_4510_cv8.nii
# saving lrp_map_4515_cv8.nii
# saving lrp_map_4521_cv8.nii
# saving lrp_map_4524_cv8.nii
# saving lrp_map_4531_cv8.nii
# saving lrp_map_4538_cv8.nii
# saving lrp_map_4548_cv8.nii
# saving lrp_map_4562_cv8.nii
# saving lrp_map_4582_cv8.nii
# saving lrp_map_4584_cv8.nii
# saving lrp_map_4590_cv8.nii
# saving lrp_map_4595_cv8.nii
# saving lrp_map_4596_cv8.nii
# saving lrp_map_4605_cv8.nii
# saving lrp_map_4611_cv8.nii
# saving lrp_map_4626_cv8.nii
# saving lrp_map_4629_cv8.nii
# saving lrp_map_4631_cv8.nii
# saving lrp_map_4636_cv8.nii
# saving lrp_map_4646_cv8.nii
# saving lrp_map_4653_cv8.nii
# saving lrp_map_4654_cv8.nii
# saving lrp_map_4668_cv8.nii
# saving lrp_map_4671_cv8.nii
# saving lrp_map_4675_cv8.nii
# saving lrp_map_4689_cv8.nii
# saving lrp_map_4711_cv8.nii
# saving lrp_map_4712_cv8.nii
# saving lrp_map_4713_cv8.nii
# saving lrp_map_4715_cv8.nii
# saving lrp_map_4720_cv8.nii
# saving lrp_map_4721_cv8.nii
# saving lrp_map_4722_cv8.nii
# saving lrp_map_4723_cv8.nii
# saving lrp_map_4736_cv8.nii
# saving lrp_map_4741_cv8.nii
# saving lrp_map_4743_cv8.nii
# saving lrp_map_4746_cv8.nii
# saving lrp_map_4750_cv8.nii
# saving lrp_map_4757_cv8.nii
# saving lrp_map_4767_cv8.nii
# saving lrp_map_4769_cv8.nii
# saving lrp_map_4777_cv8.nii
# saving lrp_map_4782_cv8.nii
# saving lrp_map_4784_cv8.nii
# saving lrp_map_4793_cv8.nii
# saving lrp_map_4806_cv8.nii
# saving lrp_map_4807_cv8.nii
# saving lrp_map_4815_cv8.nii
# saving lrp_map_4817_cv8.nii
# saving lrp_map_4842_cv8.nii
# saving lrp_map_4852_cv8.nii
# saving lrp_map_4857_cv8.nii
# saving lrp_map_4869_cv8.nii
# saving lrp_map_4873_cv8.nii
# saving lrp_map_4877_cv8.nii
# saving lrp_map_4885_cv8.nii
# saving lrp_map_4888_cv8.nii
# saving lrp_map_4889_cv8.nii
# saving lrp_map_4892_cv8.nii
# saving lrp_map_4896_cv8.nii
# saving lrp_map_4902_cv8.nii
# saving lrp_map_4903_cv8.nii
# saving lrp_map_4904_cv8.nii
# saving lrp_map_4909_cv8.nii
# saving lrp_map_4918_cv8.nii
# saving lrp_map_4925_cv8.nii
# saving lrp_map_4929_cv8.nii
# saving lrp_map_4936_cv8.nii
# saving lrp_map_4943_cv8.nii
# saving lrp_map_4955_cv8.nii
# saving lrp_map_4960_cv8.nii
# saving lrp_map_4976_cv8.nii
# saving lrp_map_4989_cv8.nii
# saving lrp_map_4213_cv8.nii
# saving lrp_map_4270_cv8.nii
# saving lrp_map_0907_cv8.nii
# saving lrp_map_0981_cv8.nii
# saving lrp_map_4872_cv8.nii
# saving lrp_map_0553_cv8.nii
# saving lrp_map_0610_cv8.nii
# saving lrp_map_0498_cv8.nii
# saving lrp_map_1206_cv8.nii
# saving lrp_map_0751_cv8.nii
# saving lrp_map_0842_cv8.nii
# saving lrp_map_0419_cv8.nii
# saving lrp_map_0023_cv8.nii
# saving lrp_map_4105_cv8.nii
# saving lrp_map_4097_cv8.nii
# saving lrp_map_0159_cv8.nii
# saving lrp_map_0984_cv8.nii
# saving lrp_map_0096_cv8.nii
# saving lrp_map_0130_cv8.nii
# saving lrp_map_0031_cv8.nii
# saving lrp_map_0058_cv8.nii
# saving lrp_map_0061_cv8.nii
# saving lrp_map_0926_cv8.nii
# saving lrp_map_1190_cv8.nii
# saving lrp_map_0985_cv8.nii
# saving lrp_map_0074_cv8.nii
# saving lrp_map_0120_cv8.nii
# saving lrp_map_0618_cv8.nii
# saving lrp_map_0479_cv8.nii
# saving lrp_map_0734_cv8.nii
# saving lrp_map_0741_cv8.nii
# saving lrp_map_0920_cv8.nii
# saving lrp_map_0923_cv8.nii
# saving lrp_map_1016_cv8.nii
# saving lrp_map_1098_cv8.nii
# saving lrp_map_1352_cv8.nii
# saving lrp_map_0934_cv8.nii
# saving lrp_map_0056_cv8.nii
# saving lrp_map_0059_cv8.nii
# saving lrp_map_0257_cv8.nii
# saving lrp_map_0210_cv8.nii
# saving lrp_map_5040_cv8.nii
# saving lrp_map_0315_cv8.nii
# saving lrp_map_5023_cv8.nii
# saving lrp_map_4208_cv8.nii
# saving lrp_map_4234_cv8.nii
# saving lrp_map_0171_cv8.nii
# saving lrp_map_0172_cv8.nii
# saving lrp_map_0896_cv8.nii
# saving lrp_map_4050_cv8.nii
# saving lrp_map_0352_cv8.nii
# saving lrp_map_0047_cv8.nii
# saving lrp_map_0069_cv8.nii
# saving lrp_map_1286_cv8.nii
# saving lrp_map_0173_cv8.nii
# saving lrp_map_0657_cv8.nii
# saving lrp_map_1232_cv8.nii
# saving lrp_map_0113_cv8.nii
# saving lrp_map_0680_cv8.nii
# saving lrp_map_0112_cv8.nii
# saving lrp_map_0260_cv8.nii
# saving lrp_map_4198_cv8.nii
# saving lrp_map_0229_cv8.nii
# saving lrp_map_0272_cv8.nii
# saving lrp_map_0545_cv8.nii
# saving lrp_map_0863_cv8.nii
# saving lrp_map_0886_cv8.nii
# saving lrp_map_0969_cv8.nii
# saving lrp_map_0186_cv8.nii
# saving lrp_map_0301_cv8.nii
# saving lrp_map_0668_cv8.nii
# saving lrp_map_0722_cv8.nii
# saving lrp_map_0767_cv8.nii
# saving lrp_map_6051_cv8.nii
# saving lrp_map_4255_cv8.nii
# saving lrp_map_0021_cv8.nii
# saving lrp_map_0089_cv8.nii
# saving lrp_map_0295_cv8.nii
# saving lrp_map_0311_cv8.nii
# saving lrp_map_0413_cv8.nii
# saving lrp_map_1195_cv8.nii
# saving lrp_map_1202_cv8.nii
# saving lrp_map_1261_cv8.nii
# saving lrp_map_1280_cv8.nii
# saving lrp_map_4003_cv8.nii
# saving lrp_map_4010_cv8.nii
# saving lrp_map_4014_cv8.nii
# saving lrp_map_4018_cv8.nii
# saving lrp_map_4020_cv8.nii
# saving lrp_map_4021_cv8.nii
# saving lrp_map_4026_cv8.nii
# saving lrp_map_4028_cv8.nii
# saving lrp_map_4032_cv8.nii
# saving lrp_map_4037_cv8.nii
# saving lrp_map_4041_cv8.nii
# saving lrp_map_4043_cv8.nii
# saving lrp_map_4060_cv8.nii
# saving lrp_map_4066_cv8.nii
# saving lrp_map_4075_cv8.nii
# saving lrp_map_4076_cv8.nii
# saving lrp_map_4080_cv8.nii
# saving lrp_map_4081_cv8.nii
# saving lrp_map_4082_cv8.nii
# saving lrp_map_4084_cv8.nii
# saving lrp_map_4086_cv8.nii
# saving lrp_map_4090_cv8.nii
# saving lrp_map_4092_cv8.nii
# saving lrp_map_4093_cv8.nii
# saving lrp_map_4100_cv8.nii
# saving lrp_map_4103_cv8.nii
# saving lrp_map_4104_cv8.nii
# saving lrp_map_4119_cv8.nii
# saving lrp_map_4120_cv8.nii
# saving lrp_map_4121_cv8.nii
# saving lrp_map_4125_cv8.nii
# saving lrp_map_4139_cv8.nii
# saving lrp_map_4148_cv8.nii
# saving lrp_map_4150_cv8.nii
# saving lrp_map_4151_cv8.nii
# saving lrp_map_4155_cv8.nii
# saving lrp_map_4158_cv8.nii
# saving lrp_map_4164_cv8.nii
# saving lrp_map_4173_cv8.nii
# saving lrp_map_4174_cv8.nii
# saving lrp_map_4176_cv8.nii
# saving lrp_map_4177_cv8.nii
# saving lrp_map_4179_cv8.nii
# saving lrp_map_4196_cv8.nii
# saving lrp_map_4200_cv8.nii
# saving lrp_map_4218_cv8.nii
# saving lrp_map_4222_cv8.nii
# saving lrp_map_4224_cv8.nii
# saving lrp_map_4225_cv8.nii
# saving lrp_map_4254_cv8.nii
# saving lrp_map_4262_cv8.nii
# saving lrp_map_4266_cv8.nii
# saving lrp_map_4269_cv8.nii
# saving lrp_map_4275_cv8.nii
# saving lrp_map_4276_cv8.nii
# saving lrp_map_4277_cv8.nii
# saving lrp_map_4278_cv8.nii
# saving lrp_map_4279_cv8.nii
# saving lrp_map_4288_cv8.nii
# saving lrp_map_4290_cv8.nii
# saving lrp_map_4291_cv8.nii
# saving lrp_map_4292_cv8.nii
# saving lrp_map_4308_cv8.nii
# saving lrp_map_4313_cv8.nii
# saving lrp_map_4320_cv8.nii
# saving lrp_map_4335_cv8.nii
# saving lrp_map_4337_cv8.nii
# saving lrp_map_4339_cv8.nii
# saving lrp_map_4340_cv8.nii
# saving lrp_map_4343_cv8.nii
# saving lrp_map_4345_cv8.nii
# saving lrp_map_4348_cv8.nii
# saving lrp_map_4349_cv8.nii
# saving lrp_map_4350_cv8.nii
# saving lrp_map_4352_cv8.nii
# saving lrp_map_4357_cv8.nii
# saving lrp_map_4365_cv8.nii
# saving lrp_map_4367_cv8.nii
# saving lrp_map_4369_cv8.nii
# saving lrp_map_4371_cv8.nii
# saving lrp_map_4372_cv8.nii
# saving lrp_map_4376_cv8.nii
# saving lrp_map_4382_cv8.nii
# saving lrp_map_4384_cv8.nii
# saving lrp_map_4385_cv8.nii
# saving lrp_map_4386_cv8.nii
# saving lrp_map_4387_cv8.nii
# saving lrp_map_4388_cv8.nii
# saving lrp_map_4389_cv8.nii
# saving lrp_map_4391_cv8.nii
# saving lrp_map_4393_cv8.nii
# saving lrp_map_4396_cv8.nii
# saving lrp_map_4399_cv8.nii
# saving lrp_map_4400_cv8.nii
# saving lrp_map_4401_cv8.nii
# saving lrp_map_4410_cv8.nii
# saving lrp_map_4421_cv8.nii
# saving lrp_map_4422_cv8.nii
# saving lrp_map_4424_cv8.nii
# saving lrp_map_4427_cv8.nii
# saving lrp_map_4428_cv8.nii
# saving lrp_map_4429_cv8.nii
# saving lrp_map_4433_cv8.nii
# saving lrp_map_4441_cv8.nii
# saving lrp_map_4446_cv8.nii
# saving lrp_map_4448_cv8.nii
# saving lrp_map_4449_cv8.nii
# saving lrp_map_4453_cv8.nii
# saving lrp_map_4464_cv8.nii
# saving lrp_map_4466_cv8.nii
# saving lrp_map_4469_cv8.nii
# saving lrp_map_4474_cv8.nii
# saving lrp_map_4482_cv8.nii
# saving lrp_map_4483_cv8.nii
# saving lrp_map_4485_cv8.nii
# saving lrp_map_4488_cv8.nii
# saving lrp_map_4491_cv8.nii
# saving lrp_map_4496_cv8.nii
# saving lrp_map_4499_cv8.nii
# saving lrp_map_4503_cv8.nii
# saving lrp_map_4505_cv8.nii
# saving lrp_map_4506_cv8.nii
# saving lrp_map_4508_cv8.nii
# saving lrp_map_4516_cv8.nii
# saving lrp_map_4520_cv8.nii
# saving lrp_map_4545_cv8.nii
# saving lrp_map_4552_cv8.nii
# saving lrp_map_4555_cv8.nii
# saving lrp_map_4558_cv8.nii
# saving lrp_map_4559_cv8.nii
# saving lrp_map_4560_cv8.nii
# saving lrp_map_4566_cv8.nii
# saving lrp_map_4576_cv8.nii
# saving lrp_map_4577_cv8.nii
# saving lrp_map_4578_cv8.nii
# saving lrp_map_4579_cv8.nii
# saving lrp_map_4580_cv8.nii
# saving lrp_map_4585_cv8.nii
# saving lrp_map_4586_cv8.nii
# saving lrp_map_4587_cv8.nii
# saving lrp_map_4598_cv8.nii
# saving lrp_map_4599_cv8.nii
# saving lrp_map_4604_cv8.nii
# saving lrp_map_4607_cv8.nii
# saving lrp_map_4609_cv8.nii
# saving lrp_map_4612_cv8.nii
# saving lrp_map_4616_cv8.nii
# saving lrp_map_4620_cv8.nii
# saving lrp_map_4632_cv8.nii
# saving lrp_map_4637_cv8.nii
# saving lrp_map_4638_cv8.nii
# saving lrp_map_4643_cv8.nii
# saving lrp_map_4644_cv8.nii
# saving lrp_map_4645_cv8.nii
# saving lrp_map_4649_cv8.nii
# saving lrp_map_4652_cv8.nii
# saving lrp_map_4688_cv8.nii
# saving lrp_map_4739_cv8.nii
# saving lrp_map_4762_cv8.nii
# saving lrp_map_4795_cv8.nii
# saving lrp_map_4832_cv8.nii
# saving lrp_map_4835_cv8.nii
# saving lrp_map_4843_cv8.nii
# saving lrp_map_4855_cv8.nii
# saving lrp_map_4856_cv8.nii
# saving lrp_map_4878_cv8.nii
# saving lrp_map_4900_cv8.nii
# saving lrp_map_4921_cv8.nii
# saving lrp_map_4951_cv8.nii
# saving lrp_map_4952_cv8.nii
